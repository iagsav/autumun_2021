# %% [markdown]
# # Харинов Всеволод 19-АС

# %% [markdown]
# ## Сеть 21

# %% [markdown]
# ## **Классификация изображения**

# %% [markdown]
# Подключаем библиотеки для использования EfficientNetB2

# %%
from tensorflow.keras.applications.efficientnet import EfficientNetB2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.efficientnet import preprocess_input, decode_predictions
import numpy as np

# %% [markdown]
# Cоздаем сеть EfficientNetB2 и загружаем веса, обученные на наборе данных ImageNet

# %%
model = EfficientNetB2(weights='imagenet')
# Out:
# ...
# 37445632/37432240 [==============================] - 1s 0us/step

# %% [markdown]
# 1)Лошадь

# %% [markdown]
# Загружаем изображение

# %%
img = image.load_img('/content/horse.jpg', target_size=(260, 260))
img
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F519D813D10>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %% [markdown]
# Выполняем распознование объекта

# %%
preds = model.predict(x)

# %% [markdown]
# Печатаем 3 наиболее вероятных предсказания

# %%
print('Результаты распознавания:', decode_predictions(preds ,top=3)[0])
# Out:
# ...
# 49152/35363 [=========================================] - 0s 0us/step
# Результаты распознавания: [('n02389026', 'sorrel', 0.54423445), ('n02422106', 'hartebeest', 0.007707142), ('n02105056', 'groenendael', 0.0062562074)]

# %% [markdown]
# 2)Собака

# %%
img = image.load_img('/content/dog.jpg', target_size=(260, 260))
img
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F5122C70F90>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
print('Результаты распознавания:', decode_predictions(preds ,top=3)[0])
# Out:
# Результаты распознавания: [('n02110063', 'malamute', 0.33217683), ('n02109961', 'Eskimo_dog', 0.27967814), ('n02110185', 'Siberian_husky', 0.2203091)]

# %% [markdown]
# 3)Кошка

# %%
img = image.load_img('/content/cat.jpg', target_size=(260, 260))
img
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F5122C0FD10>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
print('Результаты распознавания:', decode_predictions(preds ,top=3)[0])
# Out:
# Результаты распознавания: [('n02124075', 'Egyptian_cat', 0.45808282), ('n02113978', 'Mexican_hairless', 0.16301064), ('n02395406', 'hog', 0.018009953)]

# %% [markdown]
# 4)Самолет

# %%
img = image.load_img('/content/plain.jpg', target_size=(260, 260))
img
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F5121477A50>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
print('Результаты распознавания:', decode_predictions(preds ,top=3)[0])
# Out:
# Результаты распознавания: [('n02690373', 'airliner', 0.77372235), ('n04592741', 'wing', 0.108759016), ('n04552348', 'warplane', 0.015808059)]

# %% [markdown]
# 5)Корабль

# %%
img = image.load_img('/content/ship.jpg', target_size=(260, 260))
img
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F5122B99610>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
print('Результаты распознавания:', decode_predictions(preds ,top=3)[0])
# Out:
# Результаты распознавания: [('n04147183', 'schooner', 0.9032495), ('n03947888', 'pirate', 0.016093342), ('n04612504', 'yawl', 0.006360398)]

# %% [markdown]
# 6)Автомобиль

# %%
img = image.load_img('/content/car.jpg', target_size=(260, 260))
img
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F5122BB42D0>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
print('Результаты распознавания:', decode_predictions(preds ,top=3)[0])
# Out:
# Результаты распознавания: [('n04285008', 'sports_car', 0.7897722), ('n04037443', 'racer', 0.08438295), ('n03100240', 'convertible', 0.021490745)]

# %% [markdown]
# 7)Дом

# %%
img = image.load_img('/content/house.jpg', target_size=(260, 260))
img
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F5122BB4890>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
print('Результаты распознавания:', decode_predictions(preds ,top=3)[0])
# Out:
# Результаты распознавания: [('n03661043', 'library', 0.18280347), ('n04589890', 'window_screen', 0.11787897), ('n09332890', 'lakeside', 0.06766209)]

# %% [markdown]
# ## **cats_vs_dogs**

# %% [markdown]
# **Подготовка данных**

# %% [markdown]
# Загружаем набор данных

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !wget https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip #загружаем zip файл
# Out:
# --2021-12-09 21:30:39--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip
# Resolving download.microsoft.com (download.microsoft.com)... 23.39.36.120, 2600:1407:f800:49b::e59, 2600:1407:f800:4a5::e59
# Connecting to download.microsoft.com (download.microsoft.com)|23.39.36.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824894548 (787M) [application/octet-stream]
# Saving to: ‘kagglecatsanddogs_3367a.zip’
#
# kagglecatsanddogs_3 100%[===================>] 786.68M   136MB/s    in 5.7s
#
# 2021-12-09 21:30:45 (138 MB/s) - ‘kagglecatsanddogs_3367a.zip’ saved [824894548/824894548]

# %%
# !ls
# Out:
# car.jpg  dog.jpg  horse.jpg  kagglecatsanddogs_3367a.zip  sample_data
# cat.jpg  drive	  house.jpg  plain.jpg			  ship.jpg

# %%
# !unzip kagglecatsanddogs_3367a.zip #разархивируем данные
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: PetImages/Dog/5500.jpg
#   inflating: PetImages/Dog/5501.jpg
#   inflating: PetImages/Dog/5502.jpg
#   inflating: PetImages/Dog/5503.jpg
#   inflating: PetImages/Dog/5504.jpg
#   inflating: PetImages/Dog/5505.jpg
#   inflating: PetImages/Dog/5506.jpg
#   inflating: PetImages/Dog/5507.jpg
#   inflating: PetImages/Dog/5508.jpg
#   inflating: PetImages/Dog/5509.jpg
#   inflating: PetImages/Dog/551.jpg
#   inflating: PetImages/Dog/5510.jpg
#   inflating: PetImages/Dog/5511.jpg
#   inflating: PetImages/Dog/5512.jpg
#   inflating: PetImages/Dog/5513.jpg
#   inflating: PetImages/Dog/5514.jpg
#   inflating: PetImages/Dog/5515.jpg
#   inflating: PetImages/Dog/5516.jpg
#   inflating: PetImages/Dog/5517.jpg
#   inflating: PetImages/Dog/5518.jpg
#   inflating: PetImages/Dog/5519.jpg
#   inflating: PetImages/Dog/552.jpg
#   inflating: PetImages/Dog/5520.jpg
#   inflating: PetImages/Dog/5521.jpg
# ...

# %% [markdown]
# Подключаем необходимые библиотеки

# %%
import shutil
import os

# %% [markdown]
# Задаем константы

# %%
data_dir = '/content/PetImages/'
train_dir = 'train'
val_dir   = 'val'
test_dir  = 'test'
test_portion = 0.15
val_portion = 0.15
nb_images = 12500

# %% [markdown]
# Создаем каталоги для выборок

# %%
def create_dir(dir_name): #Функция создания каталога с двумя подкаталогами по на названию классов:cats_vs_dogs
  if os.path.exists(dir_name):
    shutil.rmtree(dir_name)
  os.makedirs(dir_name)
  os.makedirs(os.path.join(dir_name, "cats"))
  os.makedirs(os.path.join(dir_name, "dogs"))

# %%
#Создаем структуры каталогов для обучающего, проверочного и тестового набора данных
create_dir(train_dir) 
create_dir(test_dir)
create_dir(val_dir)

# %% [markdown]
# Заполняем созданные каталоги

# %%
#Функция копирывания изображений в заданный каталог
def copy_images(st, ed, src, dst):
  for i in range(st, ed):
    shutil.copy2(os.path.join(src, "Cat/" + str(i) + ".jpg"), os.path.join(dst, "cats"))
    shutil.copy2(os.path.join(src, "Dog/" + str(i) + ".jpg"), os.path.join(dst, "dogs"))

# %%
#Расчет индексов наборов данных для обучения, проверки и тестирования
start_val = int(nb_images * (1 - val_portion - test_portion))
start_tst = int(nb_images * (1 - test_portion))
print(start_val)
print(start_tst)
# Out:
# 8750
# 10625

# %%
#Копирывание изображений
copy_images(0, start_val, data_dir, train_dir)

# %%
copy_images(start_val, start_tst, data_dir, val_dir)

# %%
copy_images(start_tst, nb_images, data_dir, test_dir)

# %% [markdown]
# **Перенос обучения**

# %% [markdown]
# Подключаем необходимые модули Keras

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.applications import EfficientNetB2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Задаем константы

# %%
# Каталог с данными для обучения
train_dir = 'train'
# Каталог с данными для проверки
val_dir = 'val'
# Каталог с данными для тестирования
test_dir = 'test'
# Размеры изображения
img_width, img_height = 150, 150
# Размерность тензора на основе изображения для входных данных в нейронную сеть
# backend Tensorflow, channels_last
input_shape = (img_width, img_height, 3)
# Размер мини-выборки
batch_size = 64
# Количество изображений для обучения
nb_train_samples = 17500
# Количество изображений для проверки
nb_validation_samples = 3750
# Количество изображений для тестирования
nb_test_samples = 3750

# %% [markdown]
# Загружаем предварительно обученную нейронную сеть

# %%
EfficientNetB2_net = EfficientNetB2(weights='imagenet', #предобучение на наборе данных imagenet
                                    include_top=False, #отключение полносвязного слоя
                                    input_shape=(150, 150, 3)) #входные данные

EfficientNetB2_net.trainable = False #запрещения обучения сети VGG16
# Out:
# ...
# 31801344/31790344 [==============================] - 1s 0us/step

# %%
EfficientNetB2_net.summary() #выводим модель
# Out:
# Model: "efficientnetb2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 150, 150, 3)  0           ['input_2[0][0]']
#
#  normalization_1 (Normalization  (None, 150, 150, 3)  7          ['rescaling_1[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 151, 151, 3)  0           ['normalization_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 75, 75, 32)   864         ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 75, 75, 32)   128         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 75, 75, 32)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 75, 75, 32)  288         ['stem_activation[0][0]']
#  D)
#
# ...

# %% [markdown]
# Создаем составную сеть

# %%
model = Sequential()
model.add(EfficientNetB2_net)
model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %% [markdown]
# Печатаем информацию о составной сети

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  efficientnetb2 (Functional)  (None, 5, 5, 1408)       7768569
#
#  flatten (Flatten)           (None, 35200)             0
#
#  dense (Dense)               (None, 256)               9011456
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
#  activation_1 (Activation)   (None, 1)                 0
#
# ...
# Total params: 16,780,282
# Trainable params: 9,011,713
# Non-trainable params: 7,768,569
# _________________________________________________________________

# %% [markdown]
# Обучаем составную сеть на новом наборе данных

# %%
model.compile(loss='binary_crossentropy', #компелируем модель
              optimizer=Adam(lr=1e-5), 
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# **Создание генератора изображений**

# %%
datagen = ImageDataGenerator(rescale=1. / 255) #Генератор делит значения всех пикселов изображения на 255

# %%
#Генератор данных для обучения на основе изображений из каталога
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 17500 images belonging to 2 classes.

# %%
#Генератор данных для проверки на основе изображений из каталога
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 3750 images belonging to 2 classes.

# %%
#Генератор данных для тестирования на основе изображений из каталога
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 3750 images belonging to 2 classes.

# %% [markdown]
# Проверяем данные

# %%
import glob
from PIL import Image

images = glob.glob("/content/train/dogs/*.jpg")

for image in images:
    with open(image, 'rb') as file:
        im = Image.open(file)
        print(image, im.width, im.height, im.mode, im.format, type(im))
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# /content/train/dogs/6066.jpg 286 288 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/dogs/4169.jpg 500 375 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/dogs/1923.jpg 500 375 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/dogs/8238.jpg 288 371 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/dogs/8547.jpg 432 324 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/dogs/7089.jpg 379 279 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/dogs/5053.jpg 500 482 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/dogs/8562.jpg 380 452 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/dogs/1053.jpg 200 156 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/dogs/2909.jpg 446 262 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# ...

# %%
# !cp /content/train/cats/667.jpg /content/train/cats/666.jpg

# %%
# !cp /content/test/dogs/11703.jpg /content/test/dogs/11702.jpg

# %% [markdown]
# **Обучаем сеть с использованием генераторов**

# %%
model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=10,
    validation_data=val_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/10
# 273/273 [==============================] - ETA: 0s - loss: 0.7298 - accuracy: 0.4959
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 270
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5 bytes but only got 0. Skipping tag 271
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 272
#   " Skipping tag %s" % (size, len(data), tag)
# ...

# %% [markdown]
# Оцениваем качество работы сети с помощью генератора

# %%
scores = model.evaluate_generator(test_generator, nb_test_samples // batch_size)
print("Аккуратность на тестовых данных: %.2f%%" % (scores[1]*100))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.
# Аккуратность на тестовых данных: 49.89%

# %% [markdown]
# Проверка обученной сети

# %% [markdown]
# Кошка

# %%
img = image.load_img('/content/cat.jpg', target_size=(150, 150))
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F5120C15B50>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
threshold = 0.5

# %%
    if preds >= threshold:
        pred ="Cat"
    else:
        pred="Dog"

# %%
print('Результаты распознавания:', pred)
# Out:
# Результаты распознавания: Cat

# %% [markdown]
# Собака

# %%
img = image.load_img('/content/dog.jpg', target_size=(150, 150))
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F51203CF250>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
    if preds >= threshold:
        pred ="Cat"
    else:
        pred="Dog"

# %%
print('Результаты распознавания:', pred)
# Out:
# Результаты распознавания: Dog

# %% [markdown]
# ## **horses_or_humans**

# %% [markdown]
# **Подготовка данных**

# %% [markdown]
# Загружаем набор данных

# %%
# !wget https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Out:
# --2021-12-09 22:02:34--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.132.128, 74.125.201.128, 74.125.202.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.132.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘horse-or-human.zip’
#
# horse-or-human.zip  100%[===================>] 142.65M  36.3MB/s    in 3.4s
#
# 2021-12-09 22:02:37 (42.0 MB/s) - ‘horse-or-human.zip’ saved [149574867/149574867]

# %%
# !wget https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip
# Out:
# --2021-12-09 22:03:39--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.197.128, 173.194.198.128, 64.233.191.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.197.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11480187 (11M) [application/zip]
# Saving to: ‘validation-horse-or-human.zip’
#
# validation-horse-or 100%[===================>]  10.95M  27.3MB/s    in 0.4s
#
# 2021-12-09 22:03:41 (27.3 MB/s) - ‘validation-horse-or-human.zip’ saved [11480187/11480187]

# %% [markdown]
# Разархивируем наборы даннных

# %%
# !unzip horse-or-human.zip
# Out:
# Archive:  horse-or-human.zip
#   inflating: horses/horse01-0.png
#   inflating: horses/horse01-1.png
#   inflating: horses/horse01-2.png
#   inflating: horses/horse01-3.png
#   inflating: horses/horse01-4.png
#   inflating: horses/horse01-5.png
#   inflating: horses/horse01-6.png
#   inflating: horses/horse01-7.png
#   inflating: horses/horse01-8.png
#   inflating: horses/horse01-9.png
#   inflating: horses/horse02-0.png
#   inflating: horses/horse02-1.png
#   inflating: horses/horse02-2.png
#   inflating: horses/horse02-3.png
#   inflating: horses/horse02-4.png
#   inflating: horses/horse02-5.png
#   inflating: horses/horse02-6.png
#   inflating: horses/horse02-7.png
#   inflating: horses/horse02-8.png
#   inflating: horses/horse02-9.png
#   inflating: horses/horse03-0.png
#   inflating: horses/horse03-1.png
#   inflating: horses/horse03-2.png
#   inflating: horses/horse03-3.png
#   inflating: horses/horse03-4.png
#   inflating: horses/horse03-5.png
# ...

# %%
# !unzip validation-horse-or-human.zip
# Out:
# Archive:  validation-horse-or-human.zip
#   inflating: horses/horse1-000.png
#   inflating: horses/horse1-105.png
#   inflating: horses/horse1-122.png
#   inflating: horses/horse1-127.png
#   inflating: horses/horse1-170.png
#   inflating: horses/horse1-204.png
#   inflating: horses/horse1-224.png
#   inflating: horses/horse1-241.png
#   inflating: horses/horse1-264.png
#   inflating: horses/horse1-276.png
#   inflating: horses/horse1-298.png
#   inflating: horses/horse1-335.png
#   inflating: horses/horse1-384.png
#   inflating: horses/horse1-411.png
#   inflating: horses/horse1-436.png
#   inflating: horses/horse1-455.png
#   inflating: horses/horse1-484.png
#   inflating: horses/horse1-510.png
#   inflating: horses/horse1-539.png
#   inflating: horses/horse1-554.png
#   inflating: horses/horse1-568.png
#   inflating: horses/horse2-011.png
#   inflating: horses/horse2-040.png
#   inflating: horses/horse2-069.png
#   inflating: horses/horse2-112.png
# ...

# %% [markdown]
# Создаем каталог для изображений

# %%
# !mkdir HoH

# %%
# !cp -r /content/horses /content/HoH/horses

# %%
# !cp -r /content/humans /content/HoH/humans

# %%
# !ls /content/HoH/humans
# Out:
# human01-00.png	human06-09.png	human11-18.png	human16-27.png
# human01-01.png	human06-10.png	human11-19.png	human16-28.png
# human01-02.png	human06-11.png	human11-20.png	human16-29.png
# human01-03.png	human06-12.png	human11-21.png	human16-30.png
# human01-04.png	human06-13.png	human11-22.png	human17-00.png
# human01-05.png	human06-14.png	human11-23.png	human17-01.png
# human01-06.png	human06-15.png	human11-24.png	human17-02.png
# human01-07.png	human06-16.png	human11-25.png	human17-03.png
# human01-08.png	human06-17.png	human11-26.png	human17-04.png
# human01-09.png	human06-18.png	human11-27.png	human17-05.png
# human01-10.png	human06-19.png	human11-28.png	human17-06.png
# human01-11.png	human06-20.png	human11-29.png	human17-07.png
# human01-12.png	human06-21.png	human11-30.png	human17-08.png
# human01-13.png	human06-22.png	human12-00.png	human17-09.png
# human01-14.png	human06-23.png	human12-01.png	human17-10.png
# human01-15.png	human06-24.png	human12-02.png	human17-11.png
# ...

# %%
# !ls /content/HoH/horses
# Out:
# horse01-0.png	horse1-276.png	horse22-9.png	horse33-6.png	horse44-0.png
# horse01-1.png	horse12-7.png	horse23-0.png	horse33-7.png	horse44-1.png
# horse01-2.png	horse12-8.png	horse2-314.png	horse33-8.png	horse44-2.png
# horse01-3.png	horse1-298.png	horse23-1.png	horse3-397.png	horse4-439.png
# horse01-4.png	horse12-9.png	horse23-2.png	horse33-9.png	horse44-3.png
# horse01-5.png	horse13-0.png	horse23-3.png	horse34-0.png	horse44-4.png
# horse01-6.png	horse13-1.png	horse23-4.png	horse3-416.png	horse44-5.png
# horse01-7.png	horse13-2.png	horse23-5.png	horse34-1.png	horse4-468.png
# horse01-8.png	horse1-335.png	horse2-368.png	horse34-2.png	horse44-6.png
# horse01-9.png	horse13-3.png	horse23-6.png	horse34-3.png	horse44-7.png
# horse02-0.png	horse13-4.png	horse23-7.png	horse3-440.png	horse44-8.png
# horse02-1.png	horse13-5.png	horse2-383.png	horse34-4.png	horse4-495.png
# horse02-2.png	horse13-6.png	horse23-8.png	horse34-5.png	horse44-9.png
# ...

# %% [markdown]
# Подключаем необходимые библиотеки

# %%
import shutil
import os

# %% [markdown]
# Задаем константы

# %%
data_dir = '/content/HoH/'
train_dir = 'train'
val_dir   = 'val'
test_dir  = 'test'
test_portion = 0.15
val_portion = 0.15
nb_images = 628

# %% [markdown]
# Создаем каталоги для выборок

# %%
def create_dir(dir_name): #Функция создания каталога с двумя подкаталогами по на названию классов:cats_vs_dogs
  
  if os.path.exists(dir_name):
    shutil.rmtree(dir_name)

  os.makedirs(dir_name)
  os.makedirs(os.path.join(dir_name, "horses"))
  os.makedirs(os.path.join(dir_name, "humans"))

# %%
#Создаем структуры каталогов для обучающего, проверочного и тестового набора данных
create_dir(train_dir) 
create_dir(test_dir)
create_dir(val_dir)

# %% [markdown]
# Переименовываем изображения

# %%
i = 0
for filename in os.listdir("/content/HoH/horses"):
  os.rename(f"/content/HoH/horses/{filename}",f"/content/HoH/horses/horse{i}.png")
  i+=1
print(i)
# Out:
# 628

# %%
i = 0
for filename in os.listdir("/content/HoH/humans"):
  os.rename(f"/content/HoH/humans/{filename}",f"/content/HoH/humans/human{i}.png")
  i+=1
print(i)
# Out:
# 655

# %% [markdown]
# Заполняем созданные каталоги

# %%
#Функция копирывания изображений в заданный каталог
def copy_images(st, ed, src, dst):
  for i in range(st, ed):
    shutil.copy2(os.path.join(src, "horses/horse" + str(i) + ".png"), os.path.join(dst, "horses"))
    shutil.copy2(os.path.join(src, "humans/human" + str(i) + ".png"), os.path.join(dst, "humans"))

# %%
#Расчет индексов наборов данных для обучения, проверки и тестирования
start_val = int(nb_images * (1 - val_portion - test_portion))
start_tst = int(nb_images * (1 - test_portion))
print(start_val)
print(start_tst)
# Out:
# 439
# 533

# %%
#Копирывание изображений
copy_images(0, start_val, data_dir, train_dir)

# %%
copy_images(start_val, start_tst, data_dir, val_dir)

# %%
copy_images(start_tst, nb_images, data_dir, test_dir)

# %% [markdown]
# **Перенос обучения**

# %% [markdown]
# Подключаем необходимые модули Keras

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.applications import EfficientNetB2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Задаем константы

# %%
# Каталог с данными для обучения
train_dir = 'train'
# Каталог с данными для проверки
val_dir = 'val'
# Каталог с данными для тестирования
test_dir = 'test'
# Размеры изображения
img_width, img_height = 150, 150
# Размерность тензора на основе изображения для входных данных в нейронную сеть
# backend Tensorflow, channels_last
input_shape = (img_width, img_height, 3)
# Размер мини-выборки
batch_size = 64
# Количество изображений для обучения
nb_train_samples = 878
# Количество изображений для проверки
nb_validation_samples = 188
# Количество изображений для тестирования
nb_test_samples = 190

# %% [markdown]
# Загружаем предварительно обученную нейронную сеть

# %%
EfficientNetB2_net = EfficientNetB2(weights='imagenet', #предобучение на наборе данных imagenet
                                    include_top=False, #отключение полносвязного слоя
                                    input_shape=(150, 150, 3)) #входные данные

EfficientNetB2_net.trainable = False #запрещения обучения сети VGG16

# %%
EfficientNetB2_net.summary() #выводим модель
# Out:
# Model: "efficientnetb2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  rescaling_2 (Rescaling)        (None, 150, 150, 3)  0           ['input_3[0][0]']
#
#  normalization_2 (Normalization  (None, 150, 150, 3)  7          ['rescaling_2[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 151, 151, 3)  0           ['normalization_2[0][0]']
#
#  stem_conv (Conv2D)             (None, 75, 75, 32)   864         ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 75, 75, 32)   128         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 75, 75, 32)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 75, 75, 32)  288         ['stem_activation[0][0]']
#  D)
#
# ...

# %% [markdown]
# Создаем составную сеть

# %%
model = Sequential()
model.add(EfficientNetB2_net)
model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %% [markdown]
# Печатаем информацию о составной сети

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  efficientnetb2 (Functional)  (None, 5, 5, 1408)       7768569
#
#  flatten_1 (Flatten)         (None, 35200)             0
#
#  dense_2 (Dense)             (None, 256)               9011456
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
#  activation_3 (Activation)   (None, 1)                 0
#
# ...
# Total params: 16,780,282
# Trainable params: 9,011,713
# Non-trainable params: 7,768,569
# _________________________________________________________________

# %% [markdown]
# Обучаем составную сеть на новом наборе данных

# %%
model.compile(loss='binary_crossentropy', #компелируем модель
              optimizer=Adam(lr=1e-5), 
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
datagen = ImageDataGenerator(rescale=1. / 255) #Генератор делит значения всех пикселов изображения на 255

# %%
#Генератор данных для обучения на основе изображений из каталога
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 878 images belonging to 2 classes.

# %%
#Генератор данных для проверки на основе изображений из каталога
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 188 images belonging to 2 classes.

# %%
#Генератор данных для тестирования на основе изображений из каталога
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 190 images belonging to 2 classes.

# %% [markdown]
# Проверяем данные

# %%
import glob
from PIL import Image

images = glob.glob("/content/val/humans/*.jpg")

for image in images:
    with open(image, 'rb') as file:
        im = Image.open(file)
        print(image, im.width, im.height, im.mode, im.format, type(im))
#Ошибок не выдало

# %% [markdown]
# **Обучаем сеть с использованием генераторов**

# %%
model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=5,
    validation_data=val_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/5
# 13/13 [==============================] - 20s 781ms/step - loss: 1.1140 - accuracy: 0.4816 - val_loss: 0.7004 - val_accuracy: 0.5312
# Epoch 2/5
# 13/13 [==============================] - 7s 508ms/step - loss: 0.9528 - accuracy: 0.4730 - val_loss: 0.7151 - val_accuracy: 0.5156
# Epoch 3/5
# 13/13 [==============================] - 7s 504ms/step - loss: 0.8411 - accuracy: 0.5074 - val_loss: 0.6970 - val_accuracy: 0.4766
# Epoch 4/5
# 13/13 [==============================] - 7s 516ms/step - loss: 0.7990 - accuracy: 0.5024 - val_loss: 0.6935 - val_accuracy: 0.4922
# Epoch 5/5
# 13/13 [==============================] - 7s 503ms/step - loss: 0.7653 - accuracy: 0.5037 - val_loss: 0.7024 - val_accuracy: 0.5078

# %% [markdown]
# Оцениваем качество работы сети с помощью генератора

# %%
scores = model.evaluate_generator(test_generator, nb_test_samples // batch_size)
print("Аккуратность на тестовых данных: %.2f%%" % (scores[1]*100))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.
# Аккуратность на тестовых данных: 54.69%

# %% [markdown]
# Проверка обученной сети

# %% [markdown]
# Лошадь

# %%
img = image.load_img('/content/horse.jpg', target_size=(150, 150))
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F50ACC29050>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
preds
# Out:
# array([[0.4334739]], dtype=float32)

# %%
threshold = 0.5

# %%
    if preds >= threshold:
        pred ="Human"
    else:
        pred="Horse"

# %%
print('Результаты распознавания:', pred)
# Out:
# Результаты распознавания: Horse

# %% [markdown]
# Человек

# %%
img = image.load_img('/content/human.jpg', target_size=(150, 150))
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F50ACB6E710>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
preds
# Out:
# array([[0.7947821]], dtype=float32)

# %%
threshold = 0.5

# %%
    if preds >= threshold:
        pred ="Human"
    else:
        pred="Horse"

# %%
print('Результаты распознавания:', pred)
# Out:
# Результаты распознавания: Human
