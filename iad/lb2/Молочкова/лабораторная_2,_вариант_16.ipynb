# %% [markdown]
# **Лабораторная работа №2 часть 1**

# %% [markdown]
# Импортируем сеть DenseNet201

# %%
# %tensorflow_version 2.x
from tensorflow.keras.applications.densenet import DenseNet201
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.densenet import preprocess_input, decode_predictions
import numpy as np

# %% [markdown]
# Загружаем сеть

# %%
model = DenseNet201(weights = 'imagenet')
# Out:
# ...
# 82534400/82524592 [==============================] - 2s 0us/step

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Загружаем изображение самолета

# %%
img = image.load_img('/content/drive/My Drive/plane.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FD7599E37D0>

# %% [markdown]
# Выполняем распознавание объекта

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# preds.shape

# %% [markdown]
# Печатаем три наиболее вероятных предсказания

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# ...
# 49152/35363 [=========================================] - 0s 0us/step
# Результаты распознавания:  [('n02690373', 'airliner', 0.98963076), ('n04592741', 'wing', 0.008369127), ('n04552348', 'warplane', 0.0012077355)]

# %% [markdown]
# Загружаем изображение кота

# %%
img = image.load_img('/content/drive/My Drive/cat.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FD75628F810>

# %% [markdown]
# Выполяем распознавание объекта

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02123159', 'tiger_cat', 0.58874965), ('n02123045', 'tabby', 0.40972045), ('n02127052', 'lynx', 0.0007272393)]

# %% [markdown]
# Загружаем изображение собаки

# %%
img = image.load_img('/content/drive/My Drive/dog.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F792984F550>

# %% [markdown]
# Выполяем распознавание объекта

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02088364', 'beagle', 0.35154167), ('n02088238', 'basset', 0.21895371), ('n02089867', 'Walker_hound', 0.1915503)]

# %% [markdown]
# Загружаем изображение автомобиля

# %%
img = image.load_img('/content/drive/My Drive/car.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F792B084050>

# %% [markdown]
# Выполяем распознавание объекта

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n04285008', 'sports_car', 0.49967423), ('n03459775', 'grille', 0.23693354), ('n02974003', 'car_wheel', 0.10350316)]

# %% [markdown]
# Загружаем изображение корабля

# %%
img = image.load_img('/content/drive/My Drive/ship.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F79297FF050>

# %% [markdown]
# Выполяем распознавание объекта

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n03947888', 'pirate', 0.60505664), ('n04147183', 'schooner', 0.39339355), ('n04612504', 'yawl', 0.00152541)]

# %% [markdown]
# Загружаем изображение дома

# %%
img = image.load_img('/content/drive/My Drive/house.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F792B04F350>

# %% [markdown]
# Выполяем распознавание объекта

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n03028079', 'church', 0.93570024), ('n02980441', 'castle', 0.032956287), ('n02825657', 'bell_cote', 0.008405259)]

# %% [markdown]
# Загружаем изображение лошади

# %%
img = image.load_img('/content/drive/My Drive/horse.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F792985BF50>

# %% [markdown]
# Выполяем распознавание объекта

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02389026', 'sorrel', 0.9737134), ('n02422106', 'hartebeest', 0.009571584), ('n04604644', 'worm_fence', 0.0022147382)]

# %% [markdown]
# **Лабораторная работа №2 часть 2**

# %% [markdown]
# **Скачиваем датасет cat-vs-dogs**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# !ls "/content/drive/My Drive/"
# Out:
# Mounted at /content/drive
#  BostonHousing.csv   house.jpg
#  car.jpg	     patientid_cellmapping_parasitized.csv
#  cat.jpg	    'patientid_cellmapping_uninfected (1).csv'
#  cell_images	     plane.jpg
#  cell_images.zip     ship.jpg
# 'Colab Notebooks'    test.csv
#  dog.jpg	     train.csv
#  horse.jpg

# %%
# !wget https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip
# Out:
# --2021-12-03 06:49:12--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip
# Resolving download.microsoft.com (download.microsoft.com)... 92.123.124.137, 2a02:26f0:11e:4b5::e59, 2a02:26f0:11e:4bc::e59
# Connecting to download.microsoft.com (download.microsoft.com)|92.123.124.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824894548 (787M) [application/octet-stream]
# Saving to: ‘kagglecatsanddogs_3367a.zip’
#
# kagglecatsanddogs_3 100%[===================>] 786.68M  65.6MB/s    in 12s
#
# 2021-12-03 06:49:24 (67.9 MB/s) - ‘kagglecatsanddogs_3367a.zip’ saved [824894548/824894548]

# %%
# !ls
# Out:
# drive  kagglecatsanddogs_3367a.zip  sample_data

# %%
# !unzip kagglecatsanddogs_3367a.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: PetImages/Dog/5500.jpg
#   inflating: PetImages/Dog/5501.jpg
#   inflating: PetImages/Dog/5502.jpg
#   inflating: PetImages/Dog/5503.jpg
#   inflating: PetImages/Dog/5504.jpg
#   inflating: PetImages/Dog/5505.jpg
#   inflating: PetImages/Dog/5506.jpg
#   inflating: PetImages/Dog/5507.jpg
#   inflating: PetImages/Dog/5508.jpg
#   inflating: PetImages/Dog/5509.jpg
#   inflating: PetImages/Dog/551.jpg
#   inflating: PetImages/Dog/5510.jpg
#   inflating: PetImages/Dog/5511.jpg
#   inflating: PetImages/Dog/5512.jpg
#   inflating: PetImages/Dog/5513.jpg
#   inflating: PetImages/Dog/5514.jpg
#   inflating: PetImages/Dog/5515.jpg
#   inflating: PetImages/Dog/5516.jpg
#   inflating: PetImages/Dog/5517.jpg
#   inflating: PetImages/Dog/5518.jpg
#   inflating: PetImages/Dog/5519.jpg
#   inflating: PetImages/Dog/552.jpg
#   inflating: PetImages/Dog/5520.jpg
#   inflating: PetImages/Dog/5521.jpg
# ...

# %% [markdown]
# **Подключаем нужные библиотеки, задаём константы**

# %%
import shutil
import os

# %%
data_dir = '/content/PetImages/'
train_dir = 'train'
val_dir = 'val'
test_dir = 'test'
test_portion = 0.15
val_portion = 0.15
nb_images = 12500

# %% [markdown]
# **Созадем каталоги для выборок**

# %% [markdown]
# Функция создания каталога с двумя подкаталогами по названию классов: cats и dogs

# %%
def create_directory(dir_name):
  if os.path.exists(dir_name):
    shutil.rmtree(dir_name)
  os.makedirs(dir_name)
  os.makedirs(os.path.join(dir_name, "cats"))
  os.makedirs(os.path.join(dir_name, "dogs"))

# %% [markdown]
# Создание структуры каталогов для обучающего, проверочного и тестового набора данных

# %%
create_directory(train_dir)
create_directory(val_dir)
create_directory(test_dir)

# %% [markdown]
# **Заполняем созданные каталоги**

# %% [markdown]
# Функция копирования изображений в заданный каталог. Изображения котов и собак копируются в отдельные подкаталоги

# %%
def copy_images(start_index, end_index, source_dir, dest_dir):
    for i in range(start_index, end_index):
        shutil.copy2(os.path.join(source_dir, "Cat/" + str(i) + ".jpg"), 
                    os.path.join(dest_dir, "cats"))
        shutil.copy2(os.path.join(source_dir, "Dog/" + str(i) + ".jpg"), 
                   os.path.join(dest_dir, "dogs"))

# %% [markdown]
# Расчет индексов наборов данных для обучения, проверки и тестирования

# %%
start_val = int(nb_images * (1- val_portion - test_portion))
start_tst = int(nb_images * (1 - test_portion))
print(start_val)
print(start_tst)
# Out:
# 8750
# 10625

# %% [markdown]
# Копирования изображений

# %%
copy_images(0, start_val, data_dir, train_dir)

# %%
copy_images(start_val, start_tst, data_dir, val_dir)

# %%
copy_images(start_tst, nb_images, data_dir, test_dir)

# %% [markdown]
# **Создаём генератор изображений**

# %%
#%tensorflow_version 2.x
from tensorflow.keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, Activation, Dense
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# **Обучение сети**

# %%
img_width, img_height = 150, 150
input_shape = (img_width, img_height, 3)
epochs = 2
batch_size = 128
nb_train = 17500
nb_val   = 3750
nb_test  = 3750

# %%
datagen = ImageDataGenerator()

# %% [markdown]
# Генератор данных для обучения на основе изображений из каталога

# %%
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 17500 images belonging to 2 classes.

# %% [markdown]
# Генератор данных для проверки на основе изображений из каталога

# %%
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 3750 images belonging to 2 classes.

# %% [markdown]
# Генератор данных для тестирования на основе изображений из каталога

# %%
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 3750 images belonging to 2 classes.

# %% [markdown]
# **Перенос обучения к Keras**

# %%
from tensorflow.keras.applications.densenet import DenseNet201

# %%
densenet201 = DenseNet201(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
densenet201.trainable=False
# Out:
# ...
# 74850304/74836368 [==============================] - 2s 0us/step

# %% [markdown]
# **Сеть DenseNet201**

# %%
densenet201.summary()
# Out:
# Model: "densenet201"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 156, 156, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 75, 75, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 75, 75, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 75, 75, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 77, 77, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 38, 38, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 38, 38, 64)  256         ['pool1[0][0]']
#  ization)
#
# ...

# %% [markdown]
# **Создаем составную сеть**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam

# %%
model_cat_vs_dogs = Sequential()
model_cat_vs_dogs.add(densenet201)
model_cat_vs_dogs.add(Flatten())
model_cat_vs_dogs.add(Dense(256))
model_cat_vs_dogs.add(Activation('relu'))
model_cat_vs_dogs.add(Dropout(0.5))
model_cat_vs_dogs.add(Dense(1000))
model_cat_vs_dogs.add(Activation('softmax'))

# %%
model_cat_vs_dogs.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  densenet201 (Functional)    (None, 4, 4, 1920)        18321984
#
#  flatten (Flatten)           (None, 30720)             0
#
#  dense (Dense)               (None, 256)               7864576
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1000)              257000
#
#  activation_1 (Activation)   (None, 1000)              0
#
# ...
# Total params: 26,443,560
# Trainable params: 8,121,576
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %% [markdown]
# **Компилируем составную сеть**

# %%
model_cat_vs_dogs.compile(loss='sparse_categorical_crossentropy',
optimizer=Adam(lr=1e-5),
metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
import glob
from PIL import Image

images = glob.glob("/content/train/cats/*.jpg")

for image in images:
    with open(image, 'rb') as file:
        im = Image.open(file)
        print(image, im.width, im.height, im.mode, im.format, type(im))
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# /content/train/cats/7964.jpg 500 374 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/cats/7934.jpg 456 500 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/cats/8121.jpg 500 375 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/cats/6802.jpg 336 374 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/cats/7926.jpg 500 375 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/cats/2697.jpg 320 240 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/cats/5209.jpg 500 333 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/cats/8223.jpg 500 334 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/cats/8745.jpg 320 240 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /content/train/cats/643.jpg 322 500 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# ...

# %%
# !cp /content/train/cats/667.jpg /content/train/cats/666.jpg

# %%
# !cp /content/test/dogs/11703.jpg /content/test/dogs/11702.jpg

# %% [markdown]
# **Обучаем составную сеть**

# %%
model_cat_vs_dogs.fit_generator(train_generator, 
                    steps_per_epoch = nb_train // batch_size,
                    epochs = 2,
                    validation_data  = val_generator,
                    validation_steps = nb_val // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
# Epoch 1/2
# 136/136 [==============================] - ETA: 0s - loss: 1.7436 - accuracy: 0.5242
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 270
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5 bytes but only got 0. Skipping tag 271
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 272
#   " Skipping tag %s" % (size, len(data), tag)
# ...

# %% [markdown]
# **Проверяем качество работы составной сети**

# %%
scores = model_cat_vs_dogs.evaluate_generator(test_generator, nb_test // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.

# %%
print("Аккуратность на тестовых данных: %.2f%%" %(scores[1]*100))
# Out:
# Аккуратность на тестовых данных: 74.78%

# %% [markdown]
# **Пример распознования**

# %%
from keras.preprocessing import image
from keras.applications.resnet_v2 import preprocess_input, decode_predictions
import numpy as np

# %%
img = image.load_img('/content/drive/MyDrive/dog.jpg', target_size=(150, 150))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F78B674BC10>

# %%
preds = model_cat_vs_dogs.predict(x)

# %%
preds.shape
# Out:
# (1, 1000)

# %%
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n01443537', 'goldfish', 0.7643262), ('n01440764', 'tench', 0.18076837), ('n03888257', 'parachute', 0.0013386769)]

# %%
img = image.load_img('/content/drive/MyDrive/cat.jpg', target_size=(150, 150))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F792A25A690>

# %%
preds = model_cat_vs_dogs.predict(x)

# %%
preds.shape
# Out:
# (1, 1000)

# %%
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n01440764', 'tench', 0.3778482), ('n01443537', 'goldfish', 0.23657362), ('n02108089', 'boxer', 0.007621342)]
