# %%
# %tensorflow_version 2.x #Загружаем нашу сеть с весами imagenet
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np

# %%
model = InceptionV3(weights = 'imagenet')

# %%
from google.colab import drive #Подключаемся к нашему гугл диску
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Xception, InceptionV3 #Загружаем картинку
img = image.load_img('/content/drive/My Drive/1.jpg', target_size=(299, 299))
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F37E1874CD0>

# %%
#Делаем предобработку и предсказания
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02389026', 'sorrel', 0.9191905), ('n03538406', 'horse_cart', 0.0023492896), ('n04604644', 'worm_fence', 0.0022337988)]

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/2.jpg', target_size=(299, 299))
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F37E1878690>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02109961', 'Eskimo_dog', 0.51793), ('n02115641', 'dingo', 0.10801548), ('n02110185', 'Siberian_husky', 0.058714002)]

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/3.jpg', target_size=(299, 299))
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F37E1877690>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02123045', 'tabby', 0.5469243), ('n02123159', 'tiger_cat', 0.09740003), ('n02124075', 'Egyptian_cat', 0.07873423)]

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/4.jpg', target_size=(299, 299))
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F38D5656090>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02690373', 'airliner', 0.9143031), ('n04592741', 'wing', 0.034551967), ('n04552348', 'warplane', 0.0009755672)]

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/5.jpg', target_size=(299, 299))
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F38D5611310>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n03947888', 'pirate', 0.89930326), ('n04147183', 'schooner', 0.081879094), ('n03216828', 'dock', 0.0011118385)]

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/6.jpg', target_size=(299, 299))
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F38D5642510>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02930766', 'cab', 0.24285303), ('n03770679', 'minivan', 0.23782253), ('n03459775', 'grille', 0.08715704)]

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/7.jpg', target_size=(299, 299))
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F38D55DB690>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n03930313', 'picket_fence', 0.20761119), ('n02859443', 'boathouse', 0.160763), ('n03028079', 'church', 0.11323727)]

# %%
# !wget https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip #Скачиваем архив
# Out:
# --2021-12-10 07:19:31--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.119.128, 108.177.111.128, 142.250.1.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.119.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘horse-or-human.zip.1’
#
# horse-or-human.zip. 100%[===================>] 142.65M  39.8MB/s    in 3.7s
#
# 2021-12-10 07:19:35 (38.1 MB/s) - ‘horse-or-human.zip.1’ saved [149574867/149574867]

# %%
# !unzip horse-or-human.zip
# Out:
# Archive:  horse-or-human.zip
#   inflating: horses/horse01-0.png
#   inflating: horses/horse01-1.png
#   inflating: horses/horse01-2.png
#   inflating: horses/horse01-3.png
#   inflating: horses/horse01-4.png
#   inflating: horses/horse01-5.png
#   inflating: horses/horse01-6.png
#   inflating: horses/horse01-7.png
#   inflating: horses/horse01-8.png
#   inflating: horses/horse01-9.png
#   inflating: horses/horse02-0.png
#   inflating: horses/horse02-1.png
#   inflating: horses/horse02-2.png
#   inflating: horses/horse02-3.png
#   inflating: horses/horse02-4.png
#   inflating: horses/horse02-5.png
#   inflating: horses/horse02-6.png
#   inflating: horses/horse02-7.png
#   inflating: horses/horse02-8.png
#   inflating: horses/horse02-9.png
#   inflating: horses/horse03-0.png
#   inflating: horses/horse03-1.png
#   inflating: horses/horse03-2.png
#   inflating: horses/horse03-3.png
#   inflating: horses/horse03-4.png
#   inflating: horses/horse03-5.png
# ...

# %%
# !wget https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip
# Out:
# --2021-12-10 07:19:37--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.202.128, 74.125.69.128, 64.233.182.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.202.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11480187 (11M) [application/zip]
# Saving to: ‘validation-horse-or-human.zip.1’
#
# validation-horse-or 100%[===================>]  10.95M  30.9MB/s    in 0.4s
#
# 2021-12-10 07:19:37 (30.9 MB/s) - ‘validation-horse-or-human.zip.1’ saved [11480187/11480187]

# %%
# !unzip validation-horse-or-human.zip
# Out:
# Archive:  validation-horse-or-human.zip
#   inflating: horses/horse1-000.png
#   inflating: horses/horse1-105.png
#   inflating: horses/horse1-122.png
#   inflating: horses/horse1-127.png
#   inflating: horses/horse1-170.png
#   inflating: horses/horse1-204.png
#   inflating: horses/horse1-224.png
#   inflating: horses/horse1-241.png
#   inflating: horses/horse1-264.png
#   inflating: horses/horse1-276.png
#   inflating: horses/horse1-298.png
#   inflating: horses/horse1-335.png
#   inflating: horses/horse1-384.png
#   inflating: horses/horse1-411.png
#   inflating: horses/horse1-436.png
#   inflating: horses/horse1-455.png
#   inflating: horses/horse1-484.png
#   inflating: horses/horse1-510.png
#   inflating: horses/horse1-539.png
#   inflating: horses/horse1-554.png
#   inflating: horses/horse1-568.png
#   inflating: horses/horse2-011.png
#   inflating: horses/horse2-040.png
#   inflating: horses/horse2-069.png
#   inflating: horses/horse2-112.png
# ...

# %%
import shutil
import os

# %%
i = 0
for filename in os.listdir("/content/horses"):
  os.rename(f"/content/horses/{filename}", f"/content/horses/{i}.png")
  i+=1

# %%
i = 0
for filename in os.listdir("/content/humans"):
  os.rename(f"/content/humans/{filename}", f"/content/humans/{i}.png")
  i+=1

# %%
# !mkdir /content/HuHImages
# Out:
# mkdir: cannot create directory ‘/content/HuHImages’: File exists

# %%
# !cp -r /content/horses /content/HuHImages

# %%
# !cp -r /content/humans /content/HuHImages

# %%
#Задаем константы
#Каталог с набором данных
data_dir = '/content/HuHImages/'
#Каталог с данными для обучения
train_dir = 'train'
#Каталог с данными для проверки
val_dir   = 'val'
#Каталог с данными для тестирования
test_dir  = 'test'
#Часть набора данных для тестривания
test_portion = 0.15
#Часть набора данных для проверки
val_portion = 0.15
#Количество элементов данных в одном классе
nb_images = 500

# %%
def create_dir(dir_name): #Создаем директории
  
  if os.path.exists(dir_name):
    shutil.rmtree(dir_name)

  os.makedirs(dir_name)
  os.makedirs(os.path.join(dir_name, "horses"))
  os.makedirs(os.path.join(dir_name, "humans"))

# %%
create_dir(train_dir)
create_dir(test_dir)
create_dir(val_dir)

# %%
def copy_images(st, ed, src, dst): #Копируем фотографии
  for i in range(st, ed):
    shutil.copy2(os.path.join(src, "horses/" + str(i) + ".png"), os.path.join(dst, "horses"))
    shutil.copy2(os.path.join(src, "humans/" + str(i) + ".png"), os.path.join(dst, "humans"))

# %%
start_val = int(nb_images * (1 - val_portion - test_portion)) #Делим на обучающую, валидационную и тестовую выборки
start_tst = int(nb_images * (1 - test_portion))
print(start_val)
print(start_tst)
# train - 0..8749
# val   - 8750 .. 10624
# test  - 10625 .. 12500
# Out:
# 350
# 425

# %%
# train
copy_images(0, start_val, data_dir, train_dir)

# %%
copy_images(start_val, start_tst, data_dir, val_dir)

# %%
copy_images(start_tst, nb_images, data_dir, test_dir)

# %%
img_width, img_height = 150, 150
input_shape = (img_width, img_height, 3)
epochs = 1
batch_size = 20
nb_train   = 700
nb_val     = 150
nb_test    = 150

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_generator = datagen.flow_from_directory(train_dir, #Используем генератор
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary')
# Out:
# Found 700 images belonging to 2 classes.

# %%
val_generator = datagen.flow_from_directory(val_dir, 
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary')
# Out:
# Found 150 images belonging to 2 classes.

# %%
test_generator = datagen.flow_from_directory(test_dir, 
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary')
# Out:
# Found 150 images belonging to 2 classes.

# %%
# %tensorflow_version 2.x #Также подключаем нашу сетку
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np

# %%
inception_v3_net = InceptionV3(weights = 'imagenet', include_top = False, input_shape=(150, 150, 3))
inception_v3_net.trainable=False

# %%
from tensorflow.keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, Activation, Dense
from keras.preprocessing.image import ImageDataGenerator

# %%
model = Sequential() #Создаем модель сети
model.add(inception_v3_net)
model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  flatten_2 (Flatten)         (None, 18432)             0
#
#  dense_4 (Dense)             (None, 256)               4718848
#
#  activation_474 (Activation)  (None, 256)              0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
#  activation_475 (Activation)  (None, 1)                0
#
# ...
# Total params: 26,521,889
# Trainable params: 4,719,105
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
from tensorflow import keras
opt = keras.optimizers.Adam(learning_rate = 1e-5)
model.compile(loss = 'binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
model.fit_generator(train_generator, #Переобучаем ее и выводим результат
                    steps_per_epoch = nb_train // batch_size,
                    epochs = epochs,
                    validation_data  = val_generator,
                    validation_steps = nb_val // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
# 35/35 [==============================] - 12s 217ms/step - loss: 0.2850 - accuracy: 0.8886 - val_loss: 0.0164 - val_accuracy: 1.0000

# %%
scores = model.evaluate_generator(test_generator, nb_test // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.

# %%
print(scores)
# Out:
# [0.02934647910296917, 0.9928571581840515]

# %%
# !wget https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip
# Out:
# --2021-12-10 07:19:58--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip
# Resolving download.microsoft.com (download.microsoft.com)... 184.84.168.111, 2600:1407:3c00:108c::e59, 2600:1407:3c00:10a2::e59
# Connecting to download.microsoft.com (download.microsoft.com)|184.84.168.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824894548 (787M) [application/octet-stream]
# Saving to: ‘kagglecatsanddogs_3367a.zip.1’
#
# kagglecatsanddogs_3 100%[===================>] 786.68M  74.4MB/s    in 14s
#
# 2021-12-10 07:20:13 (56.2 MB/s) - ‘kagglecatsanddogs_3367a.zip.1’ saved [824894548/824894548]

# %%
# !unzip kagglecatsanddogs_3367a.zip
# Out:
# Archive:  kagglecatsanddogs_3367a.zip
# replace PetImages/Cat/0.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
#Каталог с набором данных
data_dir = '/content/PetImages/'
#Каталог с данными для обучения
train_dir = 'train'
#Каталог с данными для проверки
val_dir   = 'val'
#Каталог с данными для тестирования
test_dir  = 'test'
#Часть набора данных для тестривания
test_portion = 0.15
#Часть набора данных для проверки
val_portion = 0.15
#Количество элементов данных в одном классе
nb_images = 12500

# %%
def create_dir(dir_name):
  
  if os.path.exists(dir_name):
    shutil.rmtree(dir_name)

  os.makedirs(dir_name)
  os.makedirs(os.path.join(dir_name, "cats"))
  os.makedirs(os.path.join(dir_name, "dogs"))

# %%
create_dir(train_dir)
create_dir(test_dir)
create_dir(val_dir)

# %%
def copy_images(st, ed, src, dst):
  for i in range(st, ed):
    shutil.copy2(os.path.join(src, "Cat/" + str(i) + ".jpg"), os.path.join(dst, "cats"))
    shutil.copy2(os.path.join(src, "Dog/" + str(i) + ".jpg"), os.path.join(dst, "dogs"))

# %%
start_val = int(nb_images * (1 - val_portion - test_portion))
start_tst = int(nb_images * (1 - test_portion))
print(start_val)
print(start_tst)
# train - 0..8749
# val   - 8750 .. 10624
# test  - 10625 .. 12500
# Out:
# 8750
# 10625

# %%
# train
copy_images(0, start_val, data_dir, train_dir)

# %%
copy_images(start_val, start_tst, data_dir, val_dir)

# %%
copy_images(start_tst, nb_images, data_dir, test_dir)

# %%
img_width, img_height = 150, 150
input_shape = (img_width, img_height, 3)
epochs = 2
batch_size = 128
nb_train   = 17500
nb_val     = 3750
nb_test    = 3750

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_generator = datagen.flow_from_directory(train_dir, 
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary')
# Out:
# Found 17500 images belonging to 2 classes.

# %%
val_generator = datagen.flow_from_directory(val_dir, 
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary')
# Out:
# Found 3750 images belonging to 2 classes.

# %%
test_generator = datagen.flow_from_directory(test_dir, 
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary')
# Out:
# Found 3750 images belonging to 2 classes.

# %%
# !cp /content/train/cats/667.jpg /content/train/cats/666.jpg
# !cp /content/test/dogs/11703.jpg /content/test/dogs/11702.jpg

# %%
# %tensorflow_version 2.x
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np

# %%
inception_v3_net = InceptionV3(weights = 'imagenet', include_top = False, input_shape=(150, 150, 3))
inception_v3_net.trainable=False

# %%
from tensorflow.keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, Activation, Dense
from keras.preprocessing.image import ImageDataGenerator

# %%
model = Sequential()
model.add(inception_v3_net)
model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  flatten_3 (Flatten)         (None, 18432)             0
#
#  dense_6 (Dense)             (None, 256)               4718848
#
#  activation_570 (Activation)  (None, 256)              0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 1)                 257
#
#  activation_571 (Activation)  (None, 1)                0
#
# ...
# Total params: 26,521,889
# Trainable params: 4,719,105
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
from tensorflow import keras
opt = keras.optimizers.Adam(learning_rate = 1e-5)
model.compile(loss = 'binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
model.fit_generator(train_generator, 
                    steps_per_epoch = nb_train // batch_size,
                    epochs = epochs,
                    validation_data  = val_generator,
                    validation_steps = nb_val // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
# Epoch 1/2
# 136/136 [==============================] - ETA: 0s - loss: 0.3111 - accuracy: 0.8956
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 270
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5 bytes but only got 0. Skipping tag 271
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 272
#   " Skipping tag %s" % (size, len(data), tag)
# ...

# %%
scores = model.evaluate_generator(test_generator, nb_test // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.

# %%
print(scores)
# Out:
# [0.09684799611568451, 0.959590494632721]
