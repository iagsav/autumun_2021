# %%
# !pip install deepface
from deepface import DeepFace
from deepface.commons import functions, realtime, distance as dst
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
def detect_face(img):
    detected_face = DeepFace.detectFace(img, detector_backend = 'dlib')
    plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
def detect_face_orig(img):
    orig = cv2.imread(img)
    plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
def verify_images(img1, img2):
    obj = DeepFace.verify(img1, img2, distance_metric='euclidean', model_name='OpenFace', detector_backend = 'dlib')
    if (obj['distance'] < 0.78) :
      print(obj['distance'])
      return True
    else :
      return False

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
def get_verification_results(result):
  print(result)

# %%
imgs = [f'/content/{i}.jpg' for i in range(1,6)]
results = []

# %%
detect_face_orig(imgs[0])

# %%
detect_face_orig(imgs[1])

# %%
detect_face_orig(imgs[2])

# %%
detect_face_orig(imgs[3])

# %%
detect_face(imgs[0])
# Out:
# Downloading...
# From: http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# To: /root/.deepface/weights/shape_predictor_5_face_landmarks.dat.bz2
# shape_predictor_5_face_landmarks.dat.bz2 is going to be downloaded
# 100%|██████████| 5.71M/5.71M [00:00<00:00, 23.9MB/s]

# %%
detect_face(imgs[1])

# %%
detect_face(imgs[3])

# %%
get_verification_results(verify_images(imgs[0], imgs[1]))
# Out:
# 0.701488357307184
# True

# %%
get_verification_results(verify_images(imgs[1], imgs[3]))
# Out:
# False
