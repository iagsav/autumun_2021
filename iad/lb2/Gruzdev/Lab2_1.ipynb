# %%
# %tensorflow_version 2.x
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np

# %%
model = InceptionV3(weights = 'imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96116736/96112376 [==============================] - 1s 0us/step
# 96124928/96112376 [==============================] - 1s 0us/step

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/horse.jpg', target_size=(299, 299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FB166D84FD0>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# 49152/35363 [=========================================] - 0s 0us/step
# Результаты распознавания:  [('n02389026', 'sorrel', 0.66016155), ('n02422106', 'hartebeest', 0.082366206), ('n02422699', 'impala', 0.018057436)]

# %%
#================================================================
#================================================================

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/dog.jpg', target_size=(299, 299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FB0F22A8A90>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02088364', 'beagle', 0.9006178), ('n02089973', 'English_foxhound', 0.01873588), ('n02089867', 'Walker_hound', 0.003972175)]

# %%
#================================================================
#================================================================

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/cat.jpeg', target_size=(299, 299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FB0F0075E10>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02123045', 'tabby', 0.78209436), ('n02123159', 'tiger_cat', 0.18442586), ('n02124075', 'Egyptian_cat', 0.0015200702)]

# %%
#================================================================
#================================================================

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/plane.jpg', target_size=(299, 299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FB0F0075E50>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02690373', 'airliner', 0.7746581), ('n04592741', 'wing', 0.1530858), ('n04552348', 'warplane', 0.0031389766)]

# %%
#================================================================
#================================================================

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/ship.jpg', target_size=(299, 299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FB0F0029A10>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n03673027', 'liner', 0.98080504), ('n03216828', 'dock', 0.0010385381), ('n04131690', 'saltshaker', 0.0010117133)]

# %%
#================================================================
#================================================================

# %%
img = image.load_img('/content/drive/My Drive/car1.jpg', target_size=(299, 299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FB0EFF84490>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n04285008', 'sports_car', 0.89241195), ('n04037443', 'racer', 0.008886696), ('n03459775', 'grille', 0.004116489)]

# %%
#================================================================
#================================================================

# %%
# Xception, InceptionV3
img = image.load_img('/content/drive/My Drive/house.jpg', target_size=(299, 299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FB0F0009150>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
#предсказания
preds = model.predict(x)
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n03930313', 'picket_fence', 0.4381598), ('n03899768', 'patio', 0.048002712), ('n03661043', 'library', 0.0396234)]
