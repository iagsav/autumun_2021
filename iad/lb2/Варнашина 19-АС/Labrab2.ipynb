# %% [markdown]
# Часть 1

# %%
# %tensorflow_version 2.x
from tensorflow.keras.applications.resnet import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet152(weights = 'imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels.h5
# 242900992/242900224 [==============================] - 2s 0us/step
# 242909184/242900224 [==============================] - 2s 0us/step

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# ResNet152
img = image.load_img('/content/drive/My Drive/самолет.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F83A5AA7510>

# %%
#предобработка
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)#предсказания
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# 49152/35363 [=========================================] - 0s 0us/step
# Результаты распознавания:  [('n04266014', 'space_shuttle', 0.8116269), ('n02690373', 'airliner', 0.17639723), ('n04592741', 'wing', 0.010825475)]

# %%
# ResNet152
img = image.load_img('/content/drive/My Drive/лошадь.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F83A5A0F750>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)#предсказания
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02113799', 'standard_poodle', 0.8741128), ('n11879895', 'rapeseed', 0.03057367), ('n02389026', 'sorrel', 0.0094617745)]

# %%
# ResNet152
img = image.load_img('/content/drive/My Drive/собака.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F83A5F3AED0>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)#предсказания
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02107142', 'Doberman', 0.99839324), ('n02106550', 'Rottweiler', 0.0005026639), ('n02089078', 'black-and-tan_coonhound', 0.0002975034)]

# %%
# ResNet152
img = image.load_img('/content/drive/My Drive/кот.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F83A3BB4690>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)#предсказания
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n02124075', 'Egyptian_cat', 0.88123506), ('n02127052', 'lynx', 0.028118124), ('n02123597', 'Siamese_cat', 0.01943876)]

# %%
# ResNet152
img = image.load_img('/content/drive/My Drive/корабль.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F83A3B62790>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)#предсказания
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n04147183', 'schooner', 0.5410789), ('n03947888', 'pirate', 0.43623775), ('n03388043', 'fountain', 0.015987849)]

# %%
# ResNet152
img = image.load_img('/content/drive/My Drive/машина.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F83A3B62C10>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)#предсказания
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n03100240', 'convertible', 0.39264613), ('n03459775', 'grille', 0.27868283), ('n04285008', 'sports_car', 0.25440243)]

# %%
# ResNet152
img = image.load_img('/content/drive/My Drive/дом.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F83A3B62810>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)#предсказания
# preds.shape

# %%
# Печатаем 3 наиболее вероятных предсказания
print('Результаты распознавания: ', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания:  [('n03930313', 'picket_fence', 0.89662987), ('n03028079', 'church', 0.059107125), ('n03899768', 'patio', 0.010243282)]

# %% [markdown]
# Часть 2

# %%
# !wget https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip #скачиваем архив
# Out:
# --2021-12-02 14:18:49--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip
# Resolving download.microsoft.com (download.microsoft.com)... 23.200.224.137, 2600:1407:3c00:1086::e59, 2600:1407:3c00:108c::e59
# Connecting to download.microsoft.com (download.microsoft.com)|23.200.224.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824894548 (787M) [application/octet-stream]
# Saving to: ‘kagglecatsanddogs_3367a.zip’
#
# kagglecatsanddogs_3 100%[===================>] 786.68M   150MB/s    in 5.3s
#
# 2021-12-02 14:18:55 (149 MB/s) - ‘kagglecatsanddogs_3367a.zip’ saved [824894548/824894548]

# %%
# !unzip kagglecatsanddogs_3367a.zip #распаковываем архив

# %%
import shutil
import os

# %%
#Создаем Каталог с набором данных
data_dir = '/content/PetImages/'
#Каталог с данными для обучения
train_dir = 'train'
#Каталог с данными для проверки
val_dir   = 'val'
#Каталог с данными для тестирования
test_dir  = 'test'
#Часть набора данных для тестривания
test_portion = 0.15
#Часть набора данных для проверки
val_portion = 0.15
#Количество элементов данных в одном классе
nb_images = 12500

# %%
def create_dir(dir_name):#создаем директории
  
  if os.path.exists(dir_name):
    shutil.rmtree(dir_name)

  os.makedirs(dir_name)
  os.makedirs(os.path.join(dir_name, "cats"))
  os.makedirs(os.path.join(dir_name, "dogs"))

# %%
create_dir(train_dir)
create_dir(test_dir)
create_dir(val_dir)

# %%
def copy_images(st, ed, src, dst):   #копируем фотографии из архива
  for i in range(st, ed):
    shutil.copy2(os.path.join(src, "Cat/" + str(i) + ".jpg"), os.path.join(dst, "cats"))
    shutil.copy2(os.path.join(src, "Dog/" + str(i) + ".jpg"), os.path.join(dst, "dogs"))

# %%
start_val = int(nb_images * (1 - val_portion - test_portion)) #делим их на обучающие, валидационные и тестовые выборки
start_tst = int(nb_images * (1 - test_portion))
print(start_val)
print(start_tst)
# train - 0..8749
# val   - 8750 .. 10624
# test  - 10625 .. 12500
# Out:
# 8750
# 10625

# %%
# train
copy_images(0, start_val, data_dir, train_dir)#копируем изображения

# %%
copy_images(start_val, start_tst, data_dir, val_dir)

# %%
copy_images(start_tst, nb_images, data_dir, test_dir)

# %%
img_width, img_height = 150, 150
input_shape = (img_width, img_height, 3)
epochs = 2
batch_size = 128 #размер минивыборки
nb_train   = 17500
nb_val     = 3750
nb_test    = 3750

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_generator = datagen.flow_from_directory(train_dir, 
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary') #загружаем train
# Out:
# Found 17500 images belonging to 2 classes.

# %%
val_generator = datagen.flow_from_directory(val_dir, 
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary') #через генератор
# Out:
# Found 3750 images belonging to 2 classes.

# %%
test_generator = datagen.flow_from_directory(test_dir, 
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary')
# Out:
# Found 3750 images belonging to 2 classes.

# %%
# !cp /content/train/cats/667.jpg /content/train/cats/666.jpg
# !cp /content/test/dogs/11703.jpg /content/test/dogs/11702.jpg

# %%
# %tensorflow_version 2.x
from tensorflow.keras.applications.resnet import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input, decode_predictions
import numpy as np

# %%
resnet = ResNet152(weights = 'imagenet', include_top = False, input_shape=(150, 150, 3))
resnet.trainable=False

# %%
from tensorflow.keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, Activation, Dense
from keras.preprocessing.image import ImageDataGenerator

# %%
model = Sequential()
model.add(resnet)
model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.summary() #выводим модель
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152 (Functional)      (None, 5, 5, 2048)        58370944
#
#  flatten_3 (Flatten)         (None, 51200)             0
#
#  dense_6 (Dense)             (None, 256)               13107456
#
#  activation_6 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 1)                 257
#
#  activation_7 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 71,478,657
# Trainable params: 13,107,713
# Non-trainable params: 58,370,944
# _________________________________________________________________

# %%
from tensorflow import keras
opt = keras.optimizers.Adam(learning_rate = 1e-5) #ограничение чтобы не возникло переобучение 
model.compile(loss = 'binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
model.fit_generator(train_generator, 
                    steps_per_epoch = nb_train // batch_size,
                    epochs = epochs,
                    validation_data  = val_generator,
                    validation_steps = nb_val // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
# Epoch 1/2
# 136/136 [==============================] - ETA: 0s - loss: 0.6964 - accuracy: 0.5636
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 270
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5 bytes but only got 0. Skipping tag 271
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 272
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 282
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 283
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20 bytes but only got 0. Skipping tag 306
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 48 bytes but only got 0. Skipping tag 532
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# 136/136 [==============================] - 191s 1s/step - loss: 0.6964 - accuracy: 0.5636 - val_loss: 0.6465 - val_accuracy: 0.6441
# Epoch 2/2
# 136/136 [==============================] - 177s 1s/step - loss: 0.6528 - accuracy: 0.6188 - val_loss: 0.6313 - val_accuracy: 0.6549

# %%
scores = model.evaluate_generator(test_generator, nb_test // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.

# %%
print(scores)
# Out:
# [0.6392339468002319, 0.6452047228813171]

# %% [markdown]
# Часть 3

# %%
# !wget https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Out:
# --2021-12-02 14:47:25--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.69.128, 64.233.182.128, 173.194.193.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.69.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘horse-or-human.zip’
#
# horse-or-human.zip  100%[===================>] 142.65M   140MB/s    in 1.0s
#
# 2021-12-02 14:47:26 (140 MB/s) - ‘horse-or-human.zip’ saved [149574867/149574867]

# %%
# !unzip horse-or-human.zip

# %%
# !wget https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip
# Out:
# --2021-12-02 14:48:29--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.69.128, 64.233.182.128, 173.194.193.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.69.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11480187 (11M) [application/zip]
# Saving to: ‘validation-horse-or-human.zip’
#
# validation-horse-or 100%[===================>]  10.95M  47.1MB/s    in 0.2s
#
# 2021-12-02 14:48:29 (47.1 MB/s) - ‘validation-horse-or-human.zip’ saved [11480187/11480187]

# %%
# !unzip validation-horse-or-human.zip

# %%
i = 0
for filename in os.listdir("/content/horses"):
  os.rename(f"/content/horses/{filename}", f"/content/horses/{i}.png")
  i+=1

# %%
i = 0
for filename in os.listdir("/content/humans"):
  os.rename(f"/content/humans/{filename}", f"/content/humans/{i}.png")
  i+=1

# %%
import shutil
import os

# %%
# !mkdir /content/HuHImages

# %%
# !cp -r /content/horses /content/HuHImages

# %%
# !cp -r /content/humans /content/HuHImages

# %%
#Каталог с набором данных
data_dir = '/content/HuHImages/'
#Каталог с данными для обучения
train_dir = 'train1'
#Каталог с данными для проверки
val_dir   = 'val1'
#Каталог с данными для тестирования
test_dir  = 'test1'
#Часть набора данных для тестривания
test_portion = 0.15
#Часть набора данных для проверки
val_portion = 0.15
#Количество элементов данных в одном классе
nb_images = 500

# %%
def create_dir(dir_name):
  
  if os.path.exists(dir_name):
    shutil.rmtree(dir_name)

  os.makedirs(dir_name)
  os.makedirs(os.path.join(dir_name, "horses"))
  os.makedirs(os.path.join(dir_name, "humans"))

# %%
create_dir(train_dir)
create_dir(test_dir)
create_dir(val_dir)

# %%
def copy_images(st, ed, src, dst):
  for i in range(st, ed):
    shutil.copy2(os.path.join(src, "horses/" + str(i) + ".png"), os.path.join(dst, "horses"))
    shutil.copy2(os.path.join(src, "humans/" + str(i) + ".png"), os.path.join(dst, "humans"))

# %%
start_val = int(nb_images * (1 - val_portion - test_portion))
start_tst = int(nb_images * (1 - test_portion))
print(start_val)
print(start_tst)
# train - 0..8749
# val   - 8750 .. 10624
# test  - 10625 .. 12500
# Out:
# 350
# 425

# %%
# train
copy_images(0, start_val, data_dir, train_dir)

# %%
copy_images(start_val, start_tst, data_dir, val_dir)

# %%
copy_images(start_tst, nb_images, data_dir, test_dir)

# %%
img_width, img_height = 150, 150
input_shape = (img_width, img_height, 3)
epochs = 1
batch_size = 20
nb_train   = 700
nb_val     = 150
nb_test    = 150

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_generator = datagen.flow_from_directory(train_dir, 
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary')
# Out:
# Found 700 images belonging to 2 classes.

# %%
val_generator = datagen.flow_from_directory(val_dir, 
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary')
# Out:
# Found 150 images belonging to 2 classes.

# %%
test_generator = datagen.flow_from_directory(test_dir, 
                                              target_size=(img_width, img_height),
                                              batch_size = batch_size,
                                              class_mode='binary')
# Out:
# Found 150 images belonging to 2 classes.

# %%
# %tensorflow_version 2.x
from tensorflow.keras.applications.resnet import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input, decode_predictions
import numpy as np

# %%
resnet = ResNet152(weights = 'imagenet', include_top = False, input_shape=(150, 150, 3))
resnet.trainable=False

# %%
from tensorflow.keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, Activation, Dense
from keras.preprocessing.image import ImageDataGenerator

# %%
model = Sequential()
model.add(resnet)
model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152 (Functional)      (None, 5, 5, 2048)        58370944
#
#  flatten_4 (Flatten)         (None, 51200)             0
#
#  dense_8 (Dense)             (None, 256)               13107456
#
#  activation_8 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 1)                 257
#
#  activation_9 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 71,478,657
# Trainable params: 13,107,713
# Non-trainable params: 58,370,944
# _________________________________________________________________

# %%
from tensorflow import keras
opt = keras.optimizers.Adam(learning_rate = 1e-5)
model.compile(loss = 'binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
model.fit_generator(train_generator, 
                    steps_per_epoch = nb_train // batch_size,
                    epochs = epochs,
                    validation_data  = val_generator,
                    validation_steps = nb_val // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
# 35/35 [==============================] - 26s 416ms/step - loss: 0.7084 - accuracy: 0.5686 - val_loss: 0.5953 - val_accuracy: 0.5929

# %%
scores = model.evaluate_generator(test_generator, nb_test // batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.

# %%
print(scores)
# Out:
# [0.6101752519607544, 0.6214285492897034]
