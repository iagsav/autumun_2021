# %% [markdown]
# Додонов Алексей 19-АС Лабораторная работа №3 Вариант 3-4

# %% [markdown]
# Устанавливаем DeepFace

# %%
pip install DeepFace
# Out:
# ...
#      |████████████████████████████████| 61 kB 4.5 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 2.3 MB 18.4 MB/s
# ...
#   Created wheel for gdown: filename=gdown-4.2.0-py3-none-any.whl size=14273 sha256=d5b011dda29a42946bfa9d82b6f7726faaeb48237836a0a47a1184e39b1d67ea
#   Stored in directory: /root/.cache/pip/wheels/8c/17/ff/58721d1fabdb87c21a0529948cf39e2be9af90ddbe4ad65944
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# ...

# %% [markdown]
# Импорт

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from time import time

# %% [markdown]
# Подключенеи гугл диска

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Прописывание каталога в диске

# %%
# !ls "/content/drive/My Drive/Colab_Data"
# Out:
# 1.jpg  2.jpg  3.jpg  4.jpg  5.jpg  6.jpg  7.jpg  videdo.mp4

# %% [markdown]
# Считывание тестовых изображений

# %%
frame_1 = cv.imread("/content/drive/My Drive/Colab_Data/1.jpg")
frame_1  = cv.cvtColor(frame_1, cv.COLOR_BGR2RGB)
frame_2 = cv.imread("/content/drive/My Drive/Colab_Data/2.jpg")
frame_2  = cv.cvtColor(frame_2, cv.COLOR_BGR2RGB)

# %%
frame_list = [frame_1, frame_2]
plt.figure(figsize=[35, 35])
for i in range(0,2):
  plt.subplot(3, 3, i+1)
  plt.imshow(frame_list[i])
plt.show()

# %% [markdown]
# Пробуем использовать верификацию

# %%
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
feature_vector = DeepFace.verify(frame_1, frame_2, model_name = "ArcFace", detector_backend='dlib')
# Out:
# arcface_weights.h5  will be downloaded to  /root/.deepface/weights/arcface_weights.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: /root/.deepface/weights/arcface_weights.h5
# 100%|██████████| 137M/137M [00:03<00:00, 43.9MB/s]
# Downloading...
# From: http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# To: /root/.deepface/weights/shape_predictor_5_face_landmarks.dat.bz2
# shape_predictor_5_face_landmarks.dat.bz2 is going to be downloaded
# 100%|██████████| 5.71M/5.71M [00:01<00:00, 4.05MB/s]

# %%
print(feature_vector)
# Out:
# {'verified': True, 'distance': 0.5169647588092482, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
