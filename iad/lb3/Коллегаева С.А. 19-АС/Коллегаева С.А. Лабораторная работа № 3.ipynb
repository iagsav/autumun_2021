# %%
# !pip install deepface
# Out:
# ...
#      |████████████████████████████████| 61 kB 3.4 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 2.3 MB 10.5 MB/s
# ...
#   Created wheel for gdown: filename=gdown-4.2.0-py3-none-any.whl size=14273 sha256=f8ab2edff32a8ceaa5acb4c6235c577e516936dcbc27a6059077b10f0e65d0ce
#   Stored in directory: /root/.cache/pip/wheels/8c/17/ff/58721d1fabdb87c21a0529948cf39e2be9af90ddbe4ad65944
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
backends = ['opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface']

# %%
detected_face = DeepFace.detectFace(img_path = "/content/drive/My Drive/ii.jpg", detector_backend = 'ssd')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img_path = "/content/drive/My Drive/iii.png", detector_backend = 'ssd')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img_path = "/content/drive/My Drive/i5.jpg", detector_backend = 'ssd')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img_path = "/content/drive/My Drive/nn.jpg", detector_backend = 'ssd')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
models = ["VGG-Face", "Facenet", "Facenet512", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib"]
result = DeepFace.verify(img1_path = "/content/drive/My Drive/iii.png", img2_path = "/content/drive/My Drive/i5.jpg", model_name = 'DeepID', detector_backend = 'ssd')

# %%
result
# Out:
# {'distance': 0.0035712548832845803,
#  'max_threshold_to_verify': 0.015,
#  'model': 'DeepID',
#  'similarity_metric': 'cosine',
#  'verified': True}

# %%
models = ["VGG-Face", "Facenet", "Facenet512", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib"]
result = DeepFace.verify(img1_path = "/content/drive/My Drive/ii.jpg", img2_path = "/content/drive/My Drive/i5.jpg", model_name = 'DeepID', detector_backend = 'ssd')

# %%
result
# Out:
# {'distance': 0.02299839271311377,
#  'max_threshold_to_verify': 0.015,
#  'model': 'DeepID',
#  'similarity_metric': 'cosine',
#  'verified': False}

# %%
models = ["VGG-Face", "Facenet", "Facenet512", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib"]
result = DeepFace.verify(img1_path = "/content/drive/My Drive/ii.jpg", img2_path = "/content/drive/My Drive/nn.jpg", model_name = 'DeepID', detector_backend = 'ssd')

# %%
result
# Out:
# {'distance': 0.05294972493222294,
#  'max_threshold_to_verify': 0.015,
#  'model': 'DeepID',
#  'similarity_metric': 'cosine',
#  'verified': False}
