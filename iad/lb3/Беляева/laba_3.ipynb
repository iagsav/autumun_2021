# %% [markdown]
# Беляева Любовь 19-АС
# Вариант - 3

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install deepface
# Out:
# ...
#      |████████████████████████████████| 61 kB 3.5 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 2.3 MB 7.4 MB/s
# ...
#   Created wheel for gdown: filename=gdown-4.2.0-py3-none-any.whl size=14273 sha256=623caf8efa1c9d8fa0353b5b646b681f55bf1eaf4a371f372d9391dd8c8e6f1b
#   Stored in directory: /root/.cache/pip/wheels/8c/17/ff/58721d1fabdb87c21a0529948cf39e2be9af90ddbe4ad65944
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# ...

# %%
from deepface import DeepFace
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing import image
import numpy as np
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import matplotlib
from skimage import io
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
img1_path = "/content/drive/MyDrive/Margo_1.jpg.opdownload" 
img2_path = "/content/drive/MyDrive/Margo_2.jpg.opdownload" 
img3_path = "/content/drive/MyDrive/Emma.jpg"
img4_path = "/content/drive/MyDrive/Emma_1.png"

# %%
orig = cv2.imread(img1_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img2_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img3_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img4_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img1_path, detector_backend = 'dlib')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица
# Out:
# Downloading...
# From: http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# To: /root/.deepface/weights/shape_predictor_5_face_landmarks.dat.bz2
# shape_predictor_5_face_landmarks.dat.bz2 is going to be downloaded
# 100%|██████████| 5.71M/5.71M [00:00<00:00, 33.9MB/s]

# %%
detected_face = DeepFace.detectFace(img2_path, detector_backend = 'dlib')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img3_path, detector_backend = 'dlib')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img4_path, detector_backend = 'dlib')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
result = DeepFace.verify(img1_path, img2_path, distance_metric='euclidean', model_name='OpenFace', detector_backend = 'dlib')
print( result["verified"])
# Out:
# openface_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/openface_weights.h5
# To: /root/.deepface/weights/openface_weights.h5
# 100%|██████████| 15.3M/15.3M [00:00<00:00, 81.4MB/s]
# False

# %%
result = DeepFace.verify(img1_path, img3_path, distance_metric='euclidean', model_name='OpenFace', detector_backend = 'dlib')
print( result["verified"])
# Out:
# True

# %%
result = DeepFace.verify(img1_path, img4_path, distance_metric='euclidean', model_name='OpenFace', detector_backend = 'dlib')
print( result["verified"])
# Out:
# False
