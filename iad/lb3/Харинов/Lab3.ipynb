# %%
# !pip install deepface
# !pip install opencv-contrib-python
from deepface import DeepFace
from deepface.commons import functions, realtime, distance as dst
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
def detect_face(img):
    detected_face = DeepFace.detectFace(img, detector_backend = 'opencv')
    plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
def detect_face_orig(img):
    orig = cv2.imread(img)
    plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
def verify_images(img1, img2):
    obj = DeepFace.verify(img1, img2, distance_metric='euclidean', model_name='OpenFace', detector_backend = 'opencv')
    if (obj['distance'] < 0.78) :
      print(obj['distance'])
      return True
    else :
      return False

# %%
def get_verification_results(result):
  print(result)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
imgs = [f'/content/{i}.jpg' for i in range(1,10)]
results = []

# %%
detect_face_orig(imgs[1])

# %%
detect_face_orig(imgs[2])

# %%
detect_face_orig(imgs[0])

# %%
detect_face_orig(imgs[6])

# %%
detect_face_orig(imgs[7])

# %%
detect_face_orig(imgs[8])

# %%
detect_face_orig(imgs[3])

# %%
detect_face_orig(imgs[4])

# %%
detect_face_orig(imgs[5])

# %%
detect_face(imgs[0])

# %%
detect_face(imgs[1])

# %%
detect_face(imgs[2])

# %%
detect_face(imgs[6])

# %%
detect_face(imgs[7])

# %%
detect_face(imgs[8])

# %%
detect_face(imgs[3])

# %%
detect_face(imgs[4])

# %%
detect_face(imgs[5])

# %%
get_verification_results(verify_images(imgs[0], imgs[1]))
# Out:
# 0.3990041916916141
# True

# %%
get_verification_results(verify_images(imgs[0], imgs[8]))
# Out:
# False

# %%
get_verification_results(verify_images(imgs[6], imgs[7]))
# Out:
# 0.7126362774124212
# True

# %%
get_verification_results(verify_images(imgs[4], imgs[5]))
# Out:
# 0.7089867046211561
# True

# %%
get_verification_results(verify_images(imgs[0], imgs[3]))
# Out:
# False

# %%
get_verification_results(verify_images(imgs[3], imgs[4]))
# Out:
# False
