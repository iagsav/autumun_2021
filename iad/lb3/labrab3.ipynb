# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install deepface

# %%
from deepface import DeepFace
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing import image
import numpy as np
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import matplotlib
from skimage import io

# %%
img1_path = "/content/drive/MyDrive/1.jpg" 
img2_path = "/content/drive/MyDrive/2.jpg" 
img3_path = "/content/drive/MyDrive/3.jpg"
img4_path = "/content/drive/MyDrive/4.jpg"
img5_path = "/content/drive/MyDrive/5.jpg"

# %%
orig = cv2.imread(img1_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img2_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img3_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img4_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img5_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img1_path, detector_backend = 'ssd')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img2_path, detector_backend = 'ssd')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img3_path, detector_backend = 'ssd')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img4_path, detector_backend = 'ssd')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img5_path, detector_backend = 'ssd')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
result = DeepFace.verify(img1_path, img2_path, distance_metric='euclidean', model_name='Facenet', detector_backend = 'ssd')
print( result)
# Out:
# {'verified': True, 'distance': 9.814315357681316, 'max_threshold_to_verify': 10, 'model': 'Facenet', 'similarity_metric': 'euclidean'}

# %%
result = DeepFace.verify(img1_path, img3_path, distance_metric='euclidean', model_name='Facenet', detector_backend = 'ssd')
print( result)
# Out:
# {'verified': True, 'distance': 9.541880183224652, 'max_threshold_to_verify': 10, 'model': 'Facenet', 'similarity_metric': 'euclidean'}

# %%
result = DeepFace.verify(img1_path, img4_path, distance_metric='euclidean', model_name='Facenet', detector_backend = 'ssd')
print( result)
# Out:
# {'verified': False, 'distance': 13.039716720850683, 'max_threshold_to_verify': 10, 'model': 'Facenet', 'similarity_metric': 'euclidean'}

# %%
result = DeepFace.verify(img1_path, img5_path, distance_metric='euclidean', model_name='Facenet', detector_backend = 'ssd')
print( result)
# Out:
# {'verified': False, 'distance': 16.219882807091814, 'max_threshold_to_verify': 10, 'model': 'Facenet', 'similarity_metric': 'euclidean'}
