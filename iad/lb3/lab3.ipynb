# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install deepface

# %%
from deepface import DeepFace
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing import image
import numpy as np
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import matplotlib
from skimage import io
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
img1_path = "/content/drive/MyDrive/1.png" 
img2_path = "/content/drive/MyDrive/2.jpg" 
img3_path = "/content/drive/MyDrive/3.jpg"
img4_path = "/content/drive/MyDrive/4.jpg"
img5_path = "/content/drive/MyDrive/5.jpg"

# %%
orig = cv2.imread(img1_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img2_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img3_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img4_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img5_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img1_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img2_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img3_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img4_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-d2b28dc4766b> in <module>()
# ----> 1 detected_face = DeepFace.detectFace(img4_path, detector_backend = 'opencv')
#       2 plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in detectFace(img_path, detector_backend, enforce_detection, align)
#     812
#     813 	img = functions.preprocess_face(img = img_path, detector_backend = detector_backend
# --> 814 		, enforce_detection = enforce_detection, align = align)[0] #preprocess_face returns (1, 224, 224, 3)
#     815         return img[:, :, ::-1] #bgr to rgb
#     816
#
# /usr/local/lib/python3.7/dist-packages/deepface/commons/functions.py in preprocess_face(img, target_size, grayscale, enforce_detection, detector_backend, return_region, align)
#     167         base_img = img.copy()
#     168
# --> 169         img, region = detect_face(img = img, detector_backend = detector_backend, grayscale = grayscale, enforce_detection = enforce_detection, align = align)
#     170
#     171         #--------------------------
#
# /usr/local/lib/python3.7/dist-packages/deepface/commons/functions.py in detect_face(img, detector_backend, grayscale, enforce_detection, align)
#     113                           return img, img_region
#     114                         else:
# --> 115                           raise ValueError("Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.")
#     116
#     117 def normalize_input(img, normalization = 'base'):
#
# ValueError: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.

# %%
detected_face = DeepFace.detectFace(img5_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
result = DeepFace.verify(img2_path, img2_path, distance_metric='euclidean', model_name='OpenFace', detector_backend = 'opencv')
print( result["verified"])
# Out:
# True

# %%
result = DeepFace.verify(img1_path, img3_path, distance_metric='euclidean', model_name='OpenFace', detector_backend = 'opencv')
print( result["verified"])
# Out:
# False

# %%
result = DeepFace.verify(img1_path, img4_path, distance_metric='euclidean', model_name='OpenFace', detector_backend = 'opencv')
print( result["verified"])
# Out:
# False

# %%
result = DeepFace.verify(img1_path, img5_path, distance_metric='euclidean', model_name='OpenFace', detector_backend = 'opencv')
print( result["verified"])
# Out:
# False
