# %% [markdown]
# # Белов Дмитрий 19-АС

# %% [markdown]
# ## Вариант 2-2

# %% [markdown]
# ### Детектор: SSD
# ### Модель: Google FaceNet

# %% [markdown]
# **Задание №1**

# %% [markdown]
# Подключение google диска

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Загружаем библиотеки

# %%
pip install deepface

# %%
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing import image
import numpy as np
from matplotlib.pyplot import imshow
import matplotlib
from skimage import io
from IPython.display import Image

# %% [markdown]
# Загружаем фотографию

# %%
img1_path ='/content/drive/My Drive/Image/img.jpg'

# %% [markdown]
# Вывод изображения до детектирования

# %%
orig = cv2.imread(img1_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Детектриуем изображение

# %%
detected_face = DeepFace.detectFace(img1_path, detector_backend = 'ssd')

# %% [markdown]
# Вывод изображения после детектирования

# %%
plt.imshow(detected_face)

# %% [markdown]
# Анализ лицевых атрибутов

# %%
obj = DeepFace.analyze(img_path = img1_path, actions = ['age', 'gender', 'race', 'emotion'], detector_backend= 'ssd')
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 8.44MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 100%|██████████| 539M/539M [00:09<00:00, 55.7MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# 100%|██████████| 537M/537M [00:09<00:00, 54.3MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# ...

# %%
obj
# Out:
# {'age': 27,
#  'dominant_emotion': 'neutral',
#  'dominant_race': 'white',
#  'emotion': {'angry': 1.7747880890965462,
#   'disgust': 0.0013891237358620856,
#   'fear': 1.25989755615592,
#   'happy': 0.0024042479708441533,
#   'neutral': 93.62071752548218,
#   'sad': 3.339971974492073,
#   'surprise': 0.000837211700854823},
#  'gender': 'Man',
#  'race': {'asian': 9.775555881243082e-06,
#   'black': 4.484495941408698e-10,
#   'indian': 2.3126449357304453e-08,
#   'latino hispanic': 0.0025174984011635164,
#   'middle eastern': 0.0002469699131192285,
#   'white': 99.99722838385274},
#  'region': {'h': 727, 'w': 573, 'x': 517, 'y': 432}}

# %% [markdown]
# **Задание №2**

# %% [markdown]
# Загружаем фотографии

# %%
img2_path = "/content/drive/MyDrive/Image/Smit.jpeg" 
img3_path = "/content/drive/MyDrive/Image/Son-Smit.jpeg" 
img4_path = "/content/drive/MyDrive/Image/Robert_Orri.jpg"

# %% [markdown]
# Выводим фотографии

# %%
orig = cv2.imread(img2_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img3_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img4_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Детектируем изображения

# %%
detected_face = DeepFace.detectFace(img2_path, detector_backend = 'ssd')
plt.imshow(detected_face)

# %%
detected_face = DeepFace.detectFace(img3_path, detector_backend = 'ssd')
plt.imshow(detected_face)

# %%
detected_face = DeepFace.detectFace(img4_path, detector_backend = 'ssd')
plt.imshow(detected_face)

# %% [markdown]
# Варификация изображений

# %%
result = DeepFace.verify(img2_path, img3_path, distance_metric='euclidean_l2', model_name='Facenet', detector_backend = 'ssd')
print( result["verified"])
# Out:
# facenet_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet_weights.h5
# To: /root/.deepface/weights/facenet_weights.h5
# 100%|██████████| 92.2M/92.2M [00:02<00:00, 38.4MB/s]
# False

# %%
result = DeepFace.verify(img2_path, img4_path, distance_metric='euclidean_l2', model_name='Facenet', detector_backend = 'ssd')
print( result["verified"])
# Out:
# False

# %% [markdown]
# **Задание №3**

# %% [markdown]
# Загружаем фотографию того же человека с поворотом головы

# %%
img5_path = "/content/drive/MyDrive/Image/Smit-3.jpg"
orig = cv2.imread(img5_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Детектируем изображение

# %%
detected_face = DeepFace.detectFace(img5_path, detector_backend = 'ssd')
plt.imshow(detected_face)

# %% [markdown]
# Проверяем устойчивость модели и детектора к повороту и наклону головы

# %%
result = DeepFace.verify(img2_path, img5_path, distance_metric='euclidean_l2', model_name='Facenet', detector_backend = 'ssd')
print( result["verified"])
# Out:
# False

# %% [markdown]
# Дополнительная проверка

# %%
img6_path = "/content/drive/MyDrive/Image/Smit-4.jpg"
orig = cv2.imread(img6_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img6_path, detector_backend = 'ssd')
plt.imshow(detected_face)

# %%
result = DeepFace.verify(img2_path, img6_path, distance_metric='euclidean_l2', model_name='Facenet', detector_backend = 'ssd')
print( result["verified"])
# Out:
# False

# %% [markdown]
# Дополнительная проверка 2

# %%
img7_path = "/content/drive/MyDrive/Image/Smit-2.jpg"
orig = cv2.imread(img7_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img7_path, detector_backend = 'ssd')
plt.imshow(detected_face)

# %%
result = DeepFace.verify(img2_path, img7_path, distance_metric='euclidean_l2', model_name='Facenet', detector_backend = 'ssd')
print( result["verified"])
# Out:
# True
