# %% [markdown]
# # Работа с данными от Mercedes
#
#
# Чтобы запускать и редактировать код, сохраните копию этого ноутбука себе (File->Save a copy in Drive...). Свою копию вы сможете изменять и запускать.

# %% [markdown]
# **Laboratory work n1 Lisin Maxim 19АСв Variant 6**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Загрузка данных с Google Drive

# %%
import pandas as pd
data = pd.read_csv("/content/drive/My Drive/IntelligentAnalysis/train.csv")

# %%
import numpy as np

# %% [markdown]
# Отображение загруженных данных

# %%
data
# Out:
#             id cat1 cat2 cat3  ...    cont12    cont13    cont14     loss
# 0            1    A    B    A  ...  0.594646  0.822493  0.714843  2213.18
# 1            2    A    B    A  ...  0.366307  0.611431  0.304496  1283.60
# 2            5    A    B    A  ...  0.373424  0.195709  0.774425  3005.09
# 3           10    B    B    A  ...  0.321570  0.605077  0.602642   939.85
# 4           11    A    B    A  ...  0.202213  0.246011  0.432606  2763.85
# ...        ...  ...  ...  ...  ...       ...       ...       ...      ...
# 188313  587620    A    B    A  ...  0.220003  0.333292  0.208216  1198.62
# 188314  587624    A    A    A  ...  0.301921  0.318646  0.305872  1108.34
# 188315  587630    A    B    A  ...  0.443374  0.339244  0.503888  5762.64
# 188316  587632    A    B    A  ...  0.852865  0.654753  0.721707  1562.87
# 188317  587633    B    A    A  ...  0.946432  0.810511  0.721460  4751.72
#
# [188318 rows x 132 columns]

# %%
data = data.drop(columns=['id'])

# %%
data
# Out:
#        cat1 cat2 cat3 cat4  ...    cont12    cont13    cont14     loss
# 0         A    B    A    B  ...  0.594646  0.822493  0.714843  2213.18
# 1         A    B    A    A  ...  0.366307  0.611431  0.304496  1283.60
# 2         A    B    A    A  ...  0.373424  0.195709  0.774425  3005.09
# 3         B    B    A    B  ...  0.321570  0.605077  0.602642   939.85
# 4         A    B    A    B  ...  0.202213  0.246011  0.432606  2763.85
# ...     ...  ...  ...  ...  ...       ...       ...       ...      ...
# 188313    A    B    A    A  ...  0.220003  0.333292  0.208216  1198.62
# 188314    A    A    A    A  ...  0.301921  0.318646  0.305872  1108.34
# 188315    A    B    A    A  ...  0.443374  0.339244  0.503888  5762.64
# 188316    A    B    A    A  ...  0.852865  0.654753  0.721707  1562.87
# 188317    B    A    A    B  ...  0.946432  0.810511  0.721460  4751.72
#
# [188318 rows x 131 columns]

# %%
subdata = data.iloc[:, 0:116]

# %%
subdata
# Out:
#        cat1 cat2 cat3 cat4 cat5 cat6  ... cat111 cat112 cat113 cat114 cat115 cat116
# 0         A    B    A    B    A    A  ...      C     AS      S      A      O     LB
# 1         A    B    A    A    A    A  ...      A     AV     BM      A      O     DP
# 2         A    B    A    A    B    A  ...      A      C     AF      A      I     GK
# 3         B    B    A    B    A    A  ...      C      N     AE      A      O     DJ
# 4         A    B    A    B    A    A  ...      C      Y     BM      A      K     CK
# ...     ...  ...  ...  ...  ...  ...  ...    ...    ...    ...    ...    ...    ...
# 188313    A    B    A    A    A    A  ...      A      G     BM      A      L     CK
# 188314    A    A    A    A    A    B  ...      A     AV     AU      E      J     DF
# 188315    A    B    A    A    A    A  ...      A      W     AF      A      K     DJ
# 188316    A    B    A    A    A    A  ...      A     AS     AJ      A      O     MD
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
subdata_encoded = subdata.apply(le.fit_transform)

# %%
subdata_encoded
# Out:
#         cat1  cat2  cat3  cat4  cat5  ...  cat112  cat113  cat114  cat115  cat116
# 0          0     1     0     1     0  ...      19      55       0      14     269
# 1          0     1     0     0     0  ...      22      38       0      14      85
# 2          0     1     0     0     1  ...      28       5       0       8     153
# 3          1     1     0     1     0  ...      39       4       0      14      79
# 4          0     1     0     1     0  ...      50      38       0      10      55
# ...      ...   ...   ...   ...   ...  ...     ...     ...     ...     ...     ...
# 188313     0     1     0     0     0  ...      32      38       0      11      55
# 188314     0     0     0     0     0  ...      22      20       4       9      75
# 188315     0     1     0     0     0  ...      48       5       0      10      79
# 188316     0     1     0     0     0  ...      19       9       0      14     295
# ...

# %%
subdata_2 = data.iloc[:, 116:130]

# %%
subdata_2
# Out:
#            cont1     cont2     cont3  ...    cont12    cont13    cont14
# 0       0.726300  0.245921  0.187583  ...  0.594646  0.822493  0.714843
# 1       0.330514  0.737068  0.592681  ...  0.366307  0.611431  0.304496
# 2       0.261841  0.358319  0.484196  ...  0.373424  0.195709  0.774425
# 3       0.321594  0.555782  0.527991  ...  0.321570  0.605077  0.602642
# 4       0.273204  0.159990  0.527991  ...  0.202213  0.246011  0.432606
# ...          ...       ...       ...  ...       ...       ...       ...
# 188313  0.347403  0.785784  0.613660  ...  0.220003  0.333292  0.208216
# 188314  0.507661  0.555782  0.549770  ...  0.301921  0.318646  0.305872
# 188315  0.484469  0.785784  0.792378  ...  0.443374  0.339244  0.503888
# 188316  0.438385  0.422197  0.298977  ...  0.852865  0.654753  0.721707
# 188317  0.907272  0.620805  0.440642  ...  0.946432  0.810511  0.721460
#
# [188318 rows x 14 columns]

# %%
subdata_encoded.reset_index(drop=True, inplace=True)
subdata_2.reset_index(drop=True, inplace=True)

# %%
data_2 = pd.concat([subdata_encoded, subdata_2], axis = 1)

# %%
data_2
# Out:
#         cat1  cat2  cat3  cat4  ...    cont11    cont12    cont13    cont14
# 0          0     1     0     1  ...  0.569745  0.594646  0.822493  0.714843
# 1          0     1     0     0  ...  0.338312  0.366307  0.611431  0.304496
# 2          0     1     0     0  ...  0.381398  0.373424  0.195709  0.774425
# 3          1     1     0     1  ...  0.327915  0.321570  0.605077  0.602642
# 4          0     1     0     1  ...  0.204687  0.202213  0.246011  0.432606
# ...      ...   ...   ...   ...  ...       ...       ...       ...       ...
# 188313     0     1     0     0  ...  0.223038  0.220003  0.333292  0.208216
# 188314     0     0     0     0  ...  0.307628  0.301921  0.318646  0.305872
# 188315     0     1     0     0  ...  0.445614  0.443374  0.339244  0.503888
# 188316     0     1     0     0  ...  0.863052  0.852865  0.654753  0.721707
# 188317     1     0     0     1  ...  0.932195  0.946432  0.810511  0.721460
#
# [188318 rows x 130 columns]

# %%
# Среднее значение
mymean = data_2.mean(axis=0)
# Стандартное отклонение
mystd = data_2.std(axis=0)
data_2 -= mymean
data_2 /= mystd
data_2
# Out:
#             cat1      cat2      cat3  ...    cont12    cont13    cont14
# 0      -0.574802  1.143633 -0.240848  ...  0.484635  1.547888  0.984891
# 1      -0.574802  1.143633 -0.240848  ... -0.605670  0.555949 -0.859468
# 2      -0.574802  1.143633 -0.240848  ... -0.571687 -1.397840  1.252690
# 3       1.739720  1.143633 -0.240848  ... -0.819287  0.526087  0.480589
# 4      -0.574802  1.143633 -0.240848  ... -1.389209 -1.161433 -0.283661
# ...          ...       ...       ...  ...       ...       ...       ...
# 188313 -0.574802  1.143633 -0.240848  ... -1.304263 -0.751235 -1.292212
# 188314 -0.574802 -0.874402 -0.240848  ... -0.913109 -0.820067 -0.853284
# 188315 -0.574802  1.143633 -0.240848  ... -0.237680 -0.723262  0.036726
# 188316 -0.574802  1.143633 -0.240848  ...  1.717616  0.759552  1.015742
# 188317  1.739720 -0.874402 -0.240848  ...  2.164393  1.491576  1.014632
#
# [188318 rows x 130 columns]

# %%
pd.set_option('display.max_columns', 500) #107, 233, 235, 268, 289, 290, 297, 293
data_2.describe()
# Out:
#                cat1          cat2          cat3          cat4          cat5  \
# count  1.883180e+05  1.883180e+05  1.883180e+05  1.883180e+05  1.883180e+05
# mean  -5.402405e-15 -2.264468e-16 -1.236509e-15  1.309893e-15 -2.338045e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -5.748021e-01 -8.744017e-01 -2.408477e-01 -6.831586e-01 -7.224394e-01
# 25%   -5.748021e-01 -8.744017e-01 -2.408477e-01 -6.831586e-01 -7.224394e-01
# 50%   -5.748021e-01 -8.744017e-01 -2.408477e-01 -6.831586e-01 -7.224394e-01
# 75%   -5.748021e-01  1.143633e+00 -2.408477e-01  1.463781e+00  1.384192e+00
# max    1.739720e+00  1.143633e+00  4.151980e+00  1.463781e+00  1.384192e+00
#
#                cat6          cat7          cat8          cat9         cat10  \
# count  1.883180e+05  1.883180e+05  1.883180e+05  1.883180e+05  1.883180e+05
# mean   4.353074e-15  6.054927e-15  1.612751e-15 -5.148437e-16  6.778004e-16
# ...

# %%
ydata = data.iloc[:, 130]

# %%
ydata
# Out:
# 0         2213.18
# 1         1283.60
# 2         3005.09
# 3          939.85
# 4         2763.85
#            ...
# 188313    1198.62
# 188314    1108.34
# 188315    5762.64
# 188316    1562.87
# 188317    4751.72
# Name: loss, Length: 188318, dtype: float64

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data_2, ydata, test_size=0.33, random_state=42)

# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(128, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(1))

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 32)                4192
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               66048
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# ...
# Total params: 74,977
# Trainable params: 74,977
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split = 0.2, verbose=2)
# Out:
# Epoch 1/20
# 3155/3155 - 7s - loss: 4602725.5000 - mae: 1345.3020 - val_loss: 4338775.0000 - val_mae: 1265.6984
# Epoch 2/20
# 3155/3155 - 6s - loss: 4090342.0000 - mae: 1273.3707 - val_loss: 4290299.0000 - val_mae: 1256.3378
# Epoch 3/20
# 3155/3155 - 6s - loss: 4020721.5000 - mae: 1261.1726 - val_loss: 4375380.0000 - val_mae: 1344.3619
# Epoch 4/20
# 3155/3155 - 6s - loss: 3966509.5000 - mae: 1252.9680 - val_loss: 4207472.5000 - val_mae: 1262.3441
# Epoch 5/20
# 3155/3155 - 6s - loss: 3924505.7500 - mae: 1247.9750 - val_loss: 4180239.7500 - val_mae: 1235.4523
# Epoch 6/20
# 3155/3155 - 6s - loss: 3900133.7500 - mae: 1242.1335 - val_loss: 4159248.7500 - val_mae: 1245.1161
# Epoch 7/20
# 3155/3155 - 6s - loss: 3879294.2500 - mae: 1239.6390 - val_loss: 4147304.5000 - val_mae: 1224.6488
# Epoch 8/20
# 3155/3155 - 6s - loss: 3848532.0000 - mae: 1236.4396 - val_loss: 4140810.0000 - val_mae: 1241.3605
# Epoch 9/20
# ...

# %%
pred = model.predict(X_test)

# %%
print(pred)
# Out:
# [[1838.2867 ]
#  [1193.6549 ]
#  [2204.8748 ]
#  ...
#  [2892.0063 ]
#  [3662.3428 ]
#  [ 644.22064]]

# %%
print("Предсказанное время:", pred[12], ", истинное время:", y_test[12])
# Out:
# Предсказанное время: [1562.4746] , истинное время: 1193.05

# %%
y_test = y_test.reset_index(drop=True)
diff = np.array([])

for i in np.arange(0, len(y_test)):
    diff = np.append(diff, np.abs(pred[i][0] - y_test[i]))

# %%
np.sort(diff)[-15:-1]
# Out:
# array([22871.89535156, 22951.35375   , 22997.49429687, 23387.09980469,
#        25284.80078125, 25910.76875   , 26705.83761719, 27284.64819336,
#        30609.58941406, 32225.50332031, 32567.80273438, 44116.03267578,
#        47156.92335937, 51951.28169922])

# %%
data = pd.read_csv("/content/drive/My Drive/IntelligentAnalysis/train.csv")

# %%
data
# Out:
#             id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10 cat11 cat12  \
# 0            1    A    B    A    B    A    A    A    A    B     A     B     A
# 1            2    A    B    A    A    A    A    A    A    B     B     A     A
# 2            5    A    B    A    A    B    A    A    A    B     B     B     B
# 3           10    B    B    A    B    A    A    A    A    B     A     A     A
# 4           11    A    B    A    B    A    A    A    A    B     B     A     B
# ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 188313  587620    A    B    A    A    A    A    A    A    B     A     A     A
# 188314  587624    A    A    A    A    A    B    A    A    A     A     A     A
# 188315  587630    A    B    A    A    A    A    A    B    B     A     A     A
# 188316  587632    A    B    A    A    A    A    A    A    B     B     A     B
# 188317  587633    B    A    A    B    A    A    A    A    A     A     A     A
#
# ...

# %%
data = data.dropna(axis = 'columns')

# %%
data
# Out:
#             id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10 cat11 cat12  \
# 0            1    A    B    A    B    A    A    A    A    B     A     B     A
# 1            2    A    B    A    A    A    A    A    A    B     B     A     A
# 2            5    A    B    A    A    B    A    A    A    B     B     B     B
# 3           10    B    B    A    B    A    A    A    A    B     A     A     A
# 4           11    A    B    A    B    A    A    A    A    B     B     A     B
# ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 188313  587620    A    B    A    A    A    A    A    A    B     A     A     A
# 188314  587624    A    A    A    A    A    B    A    A    A     A     A     A
# 188315  587630    A    B    A    A    A    A    A    B    B     A     A     A
# 188316  587632    A    B    A    A    A    A    A    A    B     B     A     B
# 188317  587633    B    A    A    B    A    A    A    A    A     A     A     A
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188318 entries, 0 to 188317
# Columns: 132 entries, id to loss
# dtypes: float64(15), int64(1), object(116)
# memory usage: 189.7+ MB

# %%
data.dtypes
# Out:
# id          int64
# cat1       object
# cat2       object
# cat3       object
# cat4       object
#            ...
# cont11    float64
# cont12    float64
# cont13    float64
# cont14    float64
# loss      float64
# Length: 132, dtype: object

# %%
data_object = data.select_dtypes(include=[object])
data_object
# Out:
#        cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10 cat11 cat12 cat13  \
# 0         A    B    A    B    A    A    A    A    B     A     B     A     A
# 1         A    B    A    A    A    A    A    A    B     B     A     A     A
# 2         A    B    A    A    B    A    A    A    B     B     B     B     B
# 3         B    B    A    B    A    A    A    A    B     A     A     A     A
# 4         A    B    A    B    A    A    A    A    B     B     A     B     A
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...   ...
# 188313    A    B    A    A    A    A    A    A    B     A     A     A     A
# 188314    A    A    A    A    A    B    A    A    A     A     A     A     A
# 188315    A    B    A    A    A    A    A    B    B     A     A     A     A
# 188316    A    B    A    A    A    A    A    A    B     B     A     B     A
# 188317    B    A    A    B    A    A    A    A    A     A     A     A     A
#
# ...

# %%
data_int = data.select_dtypes(include=[np.number])
data_int
# Out:
#             id     cont1     cont2     cont3     cont4     cont5     cont6  \
# 0            1  0.726300  0.245921  0.187583  0.789639  0.310061  0.718367
# 1            2  0.330514  0.737068  0.592681  0.614134  0.885834  0.438917
# 2            5  0.261841  0.358319  0.484196  0.236924  0.397069  0.289648
# 3           10  0.321594  0.555782  0.527991  0.373816  0.422268  0.440945
# 4           11  0.273204  0.159990  0.527991  0.473202  0.704268  0.178193
# ...        ...       ...       ...       ...       ...       ...       ...
# 188313  587620  0.347403  0.785784  0.613660  0.473202  0.939556  0.242437
# 188314  587624  0.507661  0.555782  0.549770  0.802892  0.704268  0.334270
# 188315  587630  0.484469  0.785784  0.792378  0.189137  0.482436  0.345883
# 188316  587632  0.438385  0.422197  0.298977  0.383428  0.340543  0.704364
# 188317  587633  0.907272  0.620805  0.440642  0.821574  0.281143  0.844563
#
# ...
