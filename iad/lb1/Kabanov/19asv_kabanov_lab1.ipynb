# %% [markdown]
# After incorporating feedback from the Kaggle community, as well as scientific and educational partners, the Artificial Intelligence Committee of the American Meteorological Society is excited to be running a second iteration of the How Much Did It Rain? competition.
#
# How Much Did It Rain? II is focused on solving the same core rain measurement prediction problem, but approaches it with a new and improved dataset and evaluation metric. This competition will go even further towards building a useful educational tool for universities, as well as making a meaningful contribution to continued meteorological research.
#
# Competition Description
# Rainfall is highly variable across space and time, making it notoriously tricky to measure. Rain gauges can be an effective measurement tool for a specific location, but it is impossible to have them everywhere. In order to have widespread coverage, data from weather radars is used to estimate rainfall nationwide. Unfortunately, these predictions never exactly match the measurements taken using rain gauges.
#
# Recently, in an effort to improve their rainfall predictors, the U.S. National Weather Service upgraded their radar network to be polarimetric. These polarimetric radars are able to provide higher quality data than conventional Doppler radars because they transmit radio wave pulses with both horizontal and vertical orientations.
#
# Polarimetric radar. Image courtesy NOAA
#
# Dual pulses make it easier to infer the size and type of precipitation because rain drops become flatter as they increase in size, whereas ice crystals tend to be elongated vertically.
#
# In this competition, you are given snapshots of polarimetric radar values and asked to predict the hourly rain gauge total. A word of caution: many of the gauge values in the training dataset are implausible (gauges may get clogged, for example). More details are on the data page.
#
# The training data consists of NEXRAD and MADIS data collected on 20 days between Apr and Aug 2014 over midwestern corn-growing states. Time and location information have been censored, and the data have been shuffled so that they are not ordered by time or place. The test data consists of data from the same radars and gauges over the remaining days in that month. Please see this page to understand more about polarimetric radar measurements.
#
# File descriptions
# train.zip - the training set.  This consists of radar observations at gauges in the Midwestern US over 20 days each month during the corn growing season. You are also provided the gauge observation at the end of each hour.
# test.zip - the test set.  This consists of radar observations at gauges in the Midwestern US over the remaining 10/11 days each month of the same year(s) as the training set.  You are required to predict the gauge observation at the end of each hour.
# sample_solution.zip - a sample submission file in the correct format
# sample_dask.py - Example program in Python that will produce the sample submission file.  This program applies the Marshall-Palmer relationship to the radar observations to predict the gauge observation.
# Data columns
# To understand the data, you have to realize that there are multiple radar observations over the course of an hour, and only one gauge observation (the 'Expected'). That is why there are multiple rows with the same 'Id'.
#
# The columns in the datasets are:
#
# Id:  A unique number for the set of observations over an hour at a gauge.
# minutes_past:  For each set of radar observations, the minutes past the top of the hour that the radar observations were carried out.  Radar observations are snapshots at that point in time.
#
# radardist_km:  Distance of gauge from the radar whose observations are being reported.
#
# Ref:  Radar reflectivity in km
#
# Ref_5x5_10th:   10th percentile of reflectivity values in 5x5 neighborhood
# around the gauge.
#
# Ref_5x5_50th:   50th percentile
#
# Ref_5x5_90th:   90th percentile
#
# RefComposite:  Maximum reflectivity in the vertical column above gauge.  In dBZ.
#
# RefComposite_5x5_10th
#
# RefComposite_5x5_50th
#
# RefComposite_5x5_90th
#
# RhoHV:  Correlation coefficient (unitless)
#
# RhoHV_5x5_10th
#
# RhoHV_5x5_50th
#
# RhoHV_5x5_90th
#
# Zdr:    Differential reflectivity in dB
#
# Zdr_5x5_10th
#
# Zdr_5x5_50th
#
# Zdr_5x5_90th
#
# Kdp:  Specific differential phase (deg/km)
#
# Kdp_5x5_10th
#
# Kdp_5x5_50th
#
# Kdp_5x5_90th
#
# Expected:  Actual gauge observation in mm at the end of the hour.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/"
# Out:
# 'Colab Notebooks'  'Data Files'   HMDIR   house_prices	 pics   UNIBS

# %% [markdown]
# Загрузка данных с Google Drive

# %%
import numpy as np
import pandas as pd
data = pd.read_csv("/content/drive/My Drive/HMDIR/train.csv")

# %% [markdown]
# Отображение загруженных данных

# %%
data = data.loc[:1000000]
data
# Out:
#             Id  minutes_past  ...  Kdp_5x5_90th  Expected
# 0            1             3  ...           NaN  0.254000
# 1            1            16  ...           NaN  0.254000
# 2            1            25  ...           NaN  0.254000
# 3            1            35  ...           NaN  0.254000
# 4            1            45  ...           NaN  0.254000
# ...        ...           ...  ...           ...       ...
# 999996   87817            16  ...      8.139999  5.842003
# 999997   87817            21  ...      2.470001  5.842003
# 999998   87817            26  ...      3.529999  5.842003
# 999999   87817            31  ...      7.889999  5.842003
# 1000000  87817            35  ...      9.750000  5.842003
#
# [1000001 rows x 24 columns]

# %%
data_ids = data[~np.isnan(data.loc[:,'Ref'])].Id.unique()  
##good_ids = set(data.iloc[data[first:last].notna(), 'Id'])
data = data[np.in1d(data.Id, data_ids)]

# %%
data
# Out:
#             Id  minutes_past  ...  Kdp_5x5_90th  Expected
# 6            2             1  ...      1.059998  1.016000
# 7            2             6  ...      1.409988  1.016000
# 8            2            11  ...      1.759994  1.016000
# 9            2            16  ...      1.059998  1.016000
# 10           2            21  ...      1.759994  1.016000
# ...        ...           ...  ...           ...       ...
# 999996   87817            16  ...      8.139999  5.842003
# 999997   87817            21  ...      2.470001  5.842003
# 999998   87817            26  ...      3.529999  5.842003
# 999999   87817            31  ...      7.889999  5.842003
# 1000000  87817            35  ...      9.750000  5.842003
#
# [645568 rows x 24 columns]

# %%
data = data.fillna(0.0)

# %% [markdown]
# Удаление столбца ID из набора данных

# %%
data = data.drop(columns=['Id'])

# %%
features = data.drop(columns = ['Expected'])

# %%
features
# Out:
#          minutes_past  radardist_km  ...  Kdp_5x5_50th  Kdp_5x5_90th
# 6                   1           2.0  ...     -0.350006      1.059998
# 7                   6           2.0  ...      0.000000      1.409988
# 8                  11           2.0  ...     -0.350006      1.759994
# 9                  16           2.0  ...      0.000000      1.059998
# 10                 21           2.0  ...     -0.350006      1.759994
# ...               ...           ...  ...           ...           ...
# 999996             16           6.0  ...      0.000000      8.139999
# 999997             21           6.0  ...     -0.710007      2.470001
# 999998             26           6.0  ...      0.349991      3.529999
# 999999             31           6.0  ...     -2.120010      7.889999
# 1000000            35           6.0  ...      0.000000      9.750000
#
# [645568 rows x 22 columns]

# %%
#features.describe()

# %% [markdown]
# Нормировка данных так, чтобы среднее = 0, стандартное отклонение = 1

# %%
# Среднее значение
mymean = features.mean(axis=0)
# Стандартное отклонение
mystd = features.std(axis=0)
features -= mymean
features /= mystd

# %%
features
# Out:
#          minutes_past  radardist_km  ...  Kdp_5x5_50th  Kdp_5x5_90th
# 6           -1.643490     -1.923638  ...     -0.097710     -0.315630
# 7           -1.355481     -1.923638  ...      0.133034     -0.216385
# 8           -1.067472     -1.923638  ...     -0.097710     -0.117136
# 9           -0.779464     -1.923638  ...      0.133034     -0.315630
# 10          -0.491455     -1.923638  ...     -0.097710     -0.117136
# ...               ...           ...  ...           ...           ...
# 999996      -0.779464     -0.933387  ...      0.133034      1.692006
# 999997      -0.491455     -0.933387  ...     -0.335042      0.084197
# 999998      -0.203446     -0.933387  ...      0.363768      0.384774
# 999999       0.084563     -0.933387  ...     -1.264596      1.621115
# 1000000      0.314970     -0.933387  ...      0.133034      2.148545
#
# [645568 rows x 22 columns]

# %%
features.describe()
# Out:
#        minutes_past  radardist_km  ...  Kdp_5x5_50th  Kdp_5x5_90th
# count  6.455680e+05  6.455680e+05  ...  6.455680e+05  6.455680e+05
# mean   5.147359e-16 -5.636598e-14  ...  4.264567e-14 -5.573984e-13
# std    1.000000e+00  1.000000e+00  ...  1.000000e+00  1.000000e+00
# min   -1.701092e+00 -2.418763e+00  ... -3.759620e+01 -2.313122e+01
# 25%   -8.946671e-01 -6.858244e-01  ...  1.330340e-01 -6.162076e-01
# 50%    2.696130e-02  5.686362e-02  ...  1.330340e-01 -4.148793e-01
# 75%    8.333861e-01  7.995516e-01  ...  1.330340e-01  4.046215e-01
# max    1.697413e+00  2.780053e+00  ...  7.193661e+00  2.305007e+01
#
# [8 rows x 22 columns]

# %%
y = data.iloc[:, 22]

# %%
y
# Out:
# 6          1.016000
# 7          1.016000
# 8          1.016000
# 9          1.016000
# 10         1.016000
#              ...
# 999996     5.842003
# 999997     5.842003
# 999998     5.842003
# 999999     5.842003
# 1000000    5.842003
# Name: Expected, Length: 645568, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=0.33, random_state=420)

# %%
X_train
# Out:
#         minutes_past  radardist_km  ...  Kdp_5x5_50th  Kdp_5x5_90th
# 676494     -0.030640      1.294677  ...      0.133034     -0.616208
# 975388      0.199767      0.551989  ...     -1.264596      0.977423
# 13248       1.236599      0.056864  ...     -0.097710      0.481185
# 533362     -1.182676     -1.180950  ...      0.133034     -0.616208
# 390044     -0.376251     -2.171200  ...     -1.726073      1.198603
# ...              ...           ...  ...           ...           ...
# 268241     -1.413083     -1.923638  ...      0.363768     -0.117136
# 805372      0.890988      0.056864  ...      0.133034      0.268512
# 913654     -0.030640      1.542240  ...      0.133034     -0.616208
# 996895      0.430174      1.047114  ...     -6.901228      0.484019
# 293968     -0.088242     -0.933387  ...      1.055989      1.025628
#
# [432530 rows x 22 columns]

# %%
y_test
# Out:
# 229935     0.762000
# 347466    22.860012
# 173570     1.524001
# 581777     0.508000
# 864365     3.810002
#             ...
# 458043    28.000013
# 850053     7.112004
# 410357     0.010000
# 112005    15.240008
# 451419     0.254000
# Name: Expected, Length: 213038, dtype: float64

# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(32, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 10814/10814 [==============================] - 29s 3ms/step - loss: 44797.7344 - mae: 36.7012 - val_loss: 45563.0977 - val_mae: 36.4290
# Epoch 2/10
# 10814/10814 [==============================] - 27s 3ms/step - loss: 44662.9570 - mae: 36.9826 - val_loss: 45504.3594 - val_mae: 33.3508
# Epoch 3/10
# 10814/10814 [==============================] - 27s 2ms/step - loss: 44439.0352 - mae: 37.0790 - val_loss: 45303.3867 - val_mae: 35.9981
# Epoch 4/10
# 10814/10814 [==============================] - 27s 3ms/step - loss: 44195.7383 - mae: 37.1597 - val_loss: 45257.7070 - val_mae: 32.1884
# Epoch 5/10
# 10814/10814 [==============================] - 27s 3ms/step - loss: 43896.9102 - mae: 36.9809 - val_loss: 46124.9766 - val_mae: 36.8116
# Epoch 6/10
# 10814/10814 [==============================] - 27s 2ms/step - loss: 43698.6211 - mae: 36.9840 - val_loss: 45099.2812 - val_mae: 32.1365
# Epoch 7/10
# 10814/10814 [==============================] - 27s 3ms/step - loss: 43592.2852 - mae: 36.9503 - val_loss: 44658.8281 - val_mae: 37.9365
# Epoch 8/10
# 10814/10814 [==============================] - 27s 2ms/step - loss: 43243.2891 - mae: 36.8089 - val_loss: 44469.9648 - val_mae: 36.8154
# Epoch 9/10
# 10814/10814 [==============================] - 27s 2ms/step - loss: 42885.7734 - mae: 36.6654 - val_loss: 44414.8359 - val_mae: 34.8306
# Epoch 10/10
# 10814/10814 [==============================] - 27s 2ms/step - loss: 42675.0898 - mae: 36.5027 - val_loss: 44044.6172 - val_mae: 36.8010

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                736
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               66048
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 71,521
# Trainable params: 71,521
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
pred = model.predict(X_test)

# %%
y_test = y_test.reset_index(drop=True)

# %%
print("Предсказанная стоимость:", pred[12][0], ", правильная стоимость:", y_test[12])
# Out:
# Предсказанная стоимость: 8.097883 , правильная стоимость: 36.322018

# %%
vec = np.array([])
for i in np.arange(0, len(pred)):
  vec = np.append(vec, pred[i][0])
vec
# Out:
# array([13.58607101,  7.37755585, 11.3064537 , ...,  5.2027607 ,
#        14.14209557, 39.793396  ])

# %%
diff = np.array([])

for i in np.arange(0, len(y_test)):
    diff = np.append(diff, np.abs(pred[i][0] - y_test[i]))

# %%
np.sort(diff)[-10:-1]
# Out:
# array([ 4681.48413807,  4682.89441639,  4682.89441639,  4690.44164807,
#         4690.68205983,  4701.01120907,  4702.21964032, 10375.86727321,
#        10378.23661411])

# %%
vec
# Out:
# array([13.58607101,  7.37755585, 11.3064537 , ...,  5.2027607 ,
#        14.14209557, 39.793396  ])

# %%
sorted = np.sort(pred, )
sorted
# Out:
# array([[13.586071 ],
#        [ 7.377556 ],
#        [11.306454 ],
#        ...,
#        [ 5.2027607],
#        [14.142096 ],
#        [39.793396 ]], dtype=float32)

# %%
for i in np.arange(0, len(y_test)):
    print("Предсказанная стоимость:", pred[i][0], ", правильная стоимость:", y_test[i], 'разница: ', np.abs(pred[i][0] - y_test[i]))
# Out:
# Streaming output truncated to the last 5000 lines.
# Предсказанная стоимость: 15.102652 , правильная стоимость: 545.84625 разница:  530.7435984039307
# Предсказанная стоимость: 10.9805155 , правильная стоимость: 2.2860012000000003 разница:  8.694514280041503
# Предсказанная стоимость: 8.124468 , правильная стоимость: 2.2860012000000003 разница:  5.838466649731445
# Предсказанная стоимость: 6.59002 , правильная стоимость: 0.7620004 разница:  5.828019779748535
# Предсказанная стоимость: 9.9456415 , правильная стоимость: 0.010000005 разница:  9.93564151263916
# Предсказанная стоимость: 7.5654845 , правильная стоимость: 0.7620004 разница:  6.803484123773194
# Предсказанная стоимость: 16.685946 , правильная стоимость: 5.334003 разница:  11.351942510864259
# Предсказанная стоимость: 33.138184 , правильная стоимость: 0.54000026 разница:  32.59818333375
# Предсказанная стоимость: 11.845154 , правильная стоимость: 0.7620004 разница:  11.08315340859375
# Предсказанная стоимость: 8.879139 , правильная стоимость: 2.7940012999999997 разница:  6.085137646533203
# Предсказанная стоимость: 35.36046 , правильная стоимость: 0.25400013 разница:  35.106458244023436
# Предсказанная стоимость: 17.650042 , правильная стоимость: 4.572002400000001 разница:  13.078039180200195
# Предсказанная стоимость: 46.41153 , правильная стоимость: 1.2700007 разница:  45.14152884101563
# Предсказанная стоимость: 18.304014 , правильная стоимость: 17.526009 разница:  0.7780052059326188
# Предсказанная стоимость: 133.20898 , правильная стоимость: 3.556002 разница:  129.652982375
# Предсказанная стоимость: 6.8018456 , правильная стоимость: 0.7620004 разница:  6.03984515053711
# Предсказанная стоимость: 9.268953 , правильная стоимость: 2.0320009999999997 разница:  7.2369523233642585
# Предсказанная стоимость: 7.742397 , правильная стоимость: 5.842003 разница:  1.9003938315124511
# Предсказанная стоимость: 10.372055 , правильная стоимость: 4.8260026 разница:  5.546052453710938
# Предсказанная стоимость: 7.5406876 , правильная стоимость: 1.0160004999999999 разница:  6.524687061035157
# Предсказанная стоимость: 10.404938 , правильная стоимость: 1.0160004999999999 разница:  9.388937244140624
# Предсказанная стоимость: 4.381139 , правильная стоимость: 12.446007 разница:  8.064868198425293
# Предсказанная стоимость: 6.0999374 , правильная стоимость: 1.778001 разница:  4.321936438964844
# Предсказанная стоимость: 11.544953 , правильная стоимость: 2.0320009999999997 разница:  9.512952346252442
# Предсказанная стоимость: 38.041306 , правильная стоимость: 1.0160004999999999 разница:  37.02530504199219
# Предсказанная стоимость: 97.23218 , правильная стоимость: 2969.5156 разница:  2872.283422265625
# Предсказанная стоимость: 74.35189 , правильная стоимость: 0.50800025 разница:  73.84389031396485
# Предсказанная стоимость: 8.88153 , правильная стоимость: 0.25400013 разница:  8.627529678044434
# Предсказанная стоимость: 11.683203 , правильная стоимость: 1.5240008 разница:  10.159201943530274
# Предсказанная стоимость: 21.943903 , правильная стоимость: 0.25400013 разница:  21.68990283936035
# Предсказанная стоимость: 20.385183 , правильная стоимость: 73.660034 разница:  53.27485066564941
# Предсказанная стоимость: 22.559351 , правильная стоимость: 1.0160004999999999 разница:  21.543350467407226
# Предсказанная стоимость: 4.858736 , правильная стоимость: 3.0480015 разница:  1.810734538208008
# Предсказанная стоимость: 6.5645056 , правильная стоимость: 4.318002 разница:  2.2465035770874024
# Предсказанная стоимость: 11.18239 , правильная стоимость: 6.858003999999999 разница:  4.324386213012696
# Предсказанная стоимость: 45.75509 , правильная стоимость: 10.922006 разница:  34.83308280615235
# Предсказанная стоимость: 18.34147 , правильная стоимость: 7.366003999999999 разница:  10.975466718383789
# Предсказанная стоимость: 7.859878 , правильная стоимость: 0.050000027 разница:  7.809878036201904
# Предсказанная стоимость: 21.83782 , правильная стоимость: 0.010000005 разница:  21.827820048100588
# Предсказанная стоимость: 8.00575 , правильная стоимость: 0.7620004 разница:  7.2437493024536135
# Предсказанная стоимость: 15.102602 , правильная стоимость: 0.02000001 разница:  15.082601995004882
# Предсказанная стоимость: 9.400026 , правильная стоимость: 0.25400013 разница:  9.146026191411133
# Предсказанная стоимость: 8.191647 , правильная стоимость: 1.5240008 разница:  6.667645775927735
# Предсказанная стоимость: 21.435762 , правильная стоимость: 3.3020017 разница:  18.13376070539551
# Предсказанная стоимость: 11.324087 , правильная стоимость: 1.778001 разница:  9.546086142944336
# Предсказанная стоимость: 13.600061 , правильная стоимость: 1.2700007 разница:  12.330060716625976
# Предсказанная стоимость: 17.834917 , правильная стоимость: 4.0640019999999994 разница:  13.770915068481447
# Предсказанная стоимость: 47.499283 , правильная стоимость: 0.25400013 разница:  47.24528270691406
# Предсказанная стоимость: 75.04706 , правильная стоимость: 0.7620004 разница:  74.28505770546874
# Предсказанная стоимость: 16.149471 , правильная стоимость: 3.556002 разница:  12.593469282958985
# Предсказанная стоимость: 16.514118 , правильная стоимость: 4.0640019999999994 разница:  12.45011619458008
# Предсказанная стоимость: 21.760988 , правильная стоимость: 158.00008 разница:  136.23909176452636
# Предсказанная стоимость: 15.850805 , правильная стоимость: 0.7620004 разница:  15.088804882592774
# Предсказанная стоимость: 7.3723717 , правильная стоимость: 0.25400013 разница:  7.118371543583985
# Предсказанная стоимость: 14.778583 , правильная стоимость: 4.0640019999999994 разница:  10.714580572937013
# Предсказанная стоимость: 106.75745 , правильная стоимость: 18.034010000000002 разница:  88.7234362890625
# Предсказанная стоимость: 17.188093 , правильная стоимость: 2.5400014 разница:  14.648091785424805
# Предсказанная стоимость: 4.933962 , правильная стоимость: 3.3020017 разница:  1.6319601682861329
# Предсказанная стоимость: 10.240744 , правильная стоимость: 2.5400014 разница:  7.700742237084961
# Предсказанная стоимость: 8.943703 , правильная стоимость: 1.778001 разница:  7.1657016977539065
# Предсказанная стоимость: 3.4200976 , правильная стоимость: 2.7940012999999997 разница:  0.6260962894927982
# Предсказанная стоимость: 13.09899 , правильная стоимость: 0.7620004 разница:  12.336990040368653
# Предсказанная стоимость: 10.699108 , правильная стоимость: 0.7620004 разница:  9.937107723779297
# Предсказанная стоимость: 3.2873688 , правильная стоимость: 0.25400013 разница:  3.0333686444140624
# Предсказанная стоимость: 5.7936726 , правильная стоимость: 0.50800025 разница:  5.2856723116455075
# Предсказанная стоимость: 5.7903514 , правильная стоимость: 10.668006 разница:  4.877654609161377
# Предсказанная стоимость: 11.053852 , правильная стоимость: 0.25400013 разница:  10.799851951298828
# Предсказанная стоимость: 7.3243403 , правильная стоимость: 1.0160004999999999 разница:  6.308339843475342
# Предсказанная стоимость: 66.05492 , правильная стоимость: 11.938006 разница:  54.116910381835936
# Предсказанная стоимость: 38.201958 , правильная стоимость: 0.25400013 разница:  37.94795757263672
# Предсказанная стоимость: 16.347645 , правильная стоимость: 0.25400013 разница:  16.0936446759082
# Предсказанная стоимость: 16.347645 , правильная стоимость: 1.5240008 разница:  14.823644005908204
# Предсказанная стоимость: 15.682334 , правильная стоимость: 0.25400013 разница:  15.428333816228028
# Предсказанная стоимость: 27.78361 , правильная стоимость: 459.99924000000004 разница:  432.21563060974125
# Предсказанная стоимость: 11.314471 , правильная стоимость: 0.030000018 разница:  11.28447122681201
# Предсказанная стоимость: 8.138937 , правильная стоимость: 0.50800025 разница:  7.630936746459961
# Предсказанная стоимость: 8.654306 , правильная стоимость: 2.0320009999999997 разница:  6.622305411743165
# Предсказанная стоимость: 5.904968 , правильная стоимость: 2.2860012000000003 разница:  3.6189665848815915
# Предсказанная стоимость: 5.414994 , правильная стоимость: 0.7620004 разница:  4.652993362969971
# Предсказанная стоимость: 7.002514 , правильная стоимость: 0.50800025 разница:  6.494513635498047
# Предсказанная стоимость: 6.800702 , правильная стоимость: 1.5240008 разница:  5.276701295031739
# Предсказанная стоимость: 16.43866 , правильная стоимость: 64.075035 разница:  47.63637533203125
# Предсказанная стоимость: 9.821312 , правильная стоимость: 0.10000005 разница:  9.721311900683594
# Предсказанная стоимость: 10.048705 , правильная стоимость: 2.2860012000000003 разница:  7.762703901013183
# Предсказанная стоимость: 13.128885 , правильная стоимость: 3.3020017 разница:  9.82688356916504
# Предсказанная стоимость: 38.937607 , правильная стоимость: 39.22502 разница:  0.28741318847656316
# Предсказанная стоимость: 64.402374 , правильная стоимость: 2.0320009999999997 разница:  62.370373267578124
# Предсказанная стоимость: 9.105696 , правильная стоимость: 9.144005 разница:  0.03830927551269525
# Предсказанная стоимость: 8.908712 , правильная стоимость: 0.50800025 разница:  8.40071213708496
# Предсказанная стоимость: 32.426537 , правильная стоимость: 2.2860012000000003 разница:  30.140535360058593
# Предсказанная стоимость: 42.179153 , правильная стоимость: 1.0160004999999999 разница:  41.163152942382816
# Предсказанная стоимость: 34.859764 , правильная стоимость: 4.572002400000001 разница:  30.28776169912109
# Предсказанная стоимость: 12.538025 , правильная стоимость: 0.25400013 разница:  12.28402477234375
# Предсказанная стоимость: 13.049037 , правильная стоимость: 0.010000005 разница:  13.039036974675293
# Предсказанная стоимость: 7.925151 , правильная стоимость: 1.778001 разница:  6.147149871276856
# Предсказанная стоимость: 8.106192 , правильная стоимость: 5.334003 разница:  2.772188635131836
# Предсказанная стоимость: 3.231749 , правильная стоимость: 0.50800025 разница:  2.723748807769775
# Предсказанная стоимость: 15.98503 , правильная стоимость: 1.778001 разница:  14.207029174255371
# Предсказанная стоимость: 6.4489484 , правильная стоимость: 1.5240008 разница:  4.924947583331299
# Предсказанная стоимость: 20.477633 , правильная стоимость: 0.7620004 разница:  19.715632122583006
# Предсказанная стоимость: 29.55139 , правильная стоимость: 1.0160004999999999 разница:  28.535389194213867
# Предсказанная стоимость: 39.42585 , правильная стоимость: 0.50800025 разница:  38.91784966455078
# Предсказанная стоимость: 11.322077 , правильная стоимость: 1.2700007 разница:  10.052076097485351
# Предсказанная стоимость: 6.7723126 , правильная стоимость: 2.0320009999999997 разница:  4.7403116411437995
# Предсказанная стоимость: 10.166847 , правильная стоимость: 3.556002 разница:  6.610845229003907
# Предсказанная стоимость: 22.700476 , правильная стоимость: 0.25400013 разница:  22.446475562749022
# Предсказанная стоимость: 31.311893 , правильная стоимость: 0.25400013 разница:  31.057893333134764
# Предсказанная стоимость: 14.258509 , правильная стоимость: 1.0160004999999999 разница:  13.242508182250976
# Предсказанная стоимость: 15.335358 , правильная стоимость: 7.620004 разница:  7.715353666015625
# Предсказанная стоимость: 16.821634 , правильная стоимость: 0.010000005 разница:  16.81163428760254
# Предсказанная стоимость: 10.020922 , правильная стоимость: 0.50800025 разница:  9.51292145715332
# Предсказанная стоимость: 7.9895425 , правильная стоимость: 2.2860012000000003 разница:  5.703541284283447
# Предсказанная стоимость: 8.077868 , правильная стоимость: 7.8740044000000005 разница:  0.20386406160888626
# Предсказанная стоимость: 53.42466 , правильная стоимость: 0.7620004 разница:  52.66265932900391
# Предсказанная стоимость: 8.378186 , правильная стоимость: 3.3020017 разница:  5.076184525891113
# Предсказанная стоимость: 45.165627 , правильная стоимость: 9.3980055 разница:  35.76762102587891
# Предсказанная стоимость: 40.397285 , правильная стоимость: 1.5240008 разница:  38.87328466142578
# Предсказанная стоимость: 58.26483 , правильная стоимость: 316.48416000000003 разница:  258.2193284570313
# Предсказанная стоимость: 12.446889 , правильная стоимость: 1.778001 разница:  10.66888792364502
# Предсказанная стоимость: 21.05451 , правильная стоимость: 0.25400013 разница:  20.800509986577147
# Предсказанная стоимость: 6.4127426 , правильная стоимость: 1.2700007 разница:  5.142741914746094
# Предсказанная стоимость: 7.950361 , правильная стоимость: 2.0320009999999997 разница:  5.918359774993897
# Предсказанная стоимость: 12.937409 , правильная стоимость: 10.922006 разница:  2.0154034009399417
# Предсказанная стоимость: 7.6028113 , правильная стоимость: 0.08000004 разница:  7.522811296517334
# Предсказанная стоимость: 69.534454 , правильная стоимость: 2.5400014 разница:  66.99445294570313
# Предсказанная стоимость: 11.297648 , правильная стоимость: 1.0160004999999999 разница:  10.281647929870605
# Предсказанная стоимость: 6.560398 , правильная стоимость: 1.0750006 разница:  5.4853975018066405
# Предсказанная стоимость: 20.779467 , правильная стоимость: 1.2700007 разница:  19.50946592902832
# Предсказанная стоимость: 10.546379 , правильная стоимость: 3.556002 разница:  6.990377089355469
# Предсказанная стоимость: 7.327465 , правильная стоимость: 1.5240008 разница:  5.803464257373047
# Предсказанная стоимость: 4.6378083 , правильная стоимость: 0.7620004 разница:  3.8758079229064943
# Предсказанная стоимость: 10.98736 , правильная стоимость: 0.25400013 разница:  10.733359870610352
# Предсказанная стоимость: 16.969929 , правильная стоимость: 1.0160004999999999 разница:  15.953928241455078
# Предсказанная стоимость: 23.90035 , правильная стоимость: 7.366003999999999 разница:  16.53434657067871
# Предсказанная стоимость: 20.397104 , правильная стоимость: 4.572002400000001 разница:  15.825101863305663
# Предсказанная стоимость: 13.596491 , правильная стоимость: 1.2700007 разница:  12.326490159985351
# Предсказанная стоимость: 14.383896 , правильная стоимость: 0.50800025 разница:  13.875895624023437
# Предсказанная стоимость: 14.103269 , правильная стоимость: 8.382005 разница:  5.721263623352051
# Предсказанная стоимость: 29.712706 , правильная стоимость: 2.0320009999999997 разница:  27.680704612182616
# Предсказанная стоимость: 10.26828 , правильная стоимость: 1.0160004999999999 разница:  9.252279529296874
# Предсказанная стоимость: 8.856884 , правильная стоимость: 0.25400013 разница:  8.602883872685547
# Предсказанная стоимость: 30.777409 , правильная стоимость: 0.50800025 разница:  30.269408349853517
# Предсказанная стоимость: 5.8260555 , правильная стоимость: 0.50800025 разница:  5.318055276733398
# Предсказанная стоимость: 72.54876 , правильная стоимость: 819.15045 разница:  746.6016905395508
# Предсказанная стоимость: 39.922348 , правильная стоимость: 0.50800025 разница:  39.414347772460935
# Предсказанная стоимость: 23.83757 , правильная стоимость: 1.2700007 разница:  22.567569490429687
# Предсказанная стоимость: 98.13198 , правильная стоимость: 614.42633 разница:  516.2943491040039
# Предсказанная стоимость: 16.750238 , правильная стоимость: 1.0160004999999999 разница:  15.734237918579101
# Предсказанная стоимость: 63.0261 , правильная стоимость: 614.42633 разница:  551.4002298413086
# Предсказанная стоимость: 8.526352 , правильная стоимость: 9.000005 разница:  0.4736530712890623
# Предсказанная стоимость: 7.027526 , правильная стоимость: 1.0160004999999999 разница:  6.011525401794434
# Предсказанная стоимость: 5.1141872 , правильная стоимость: 1.0160004999999999 разница:  4.098186740600586
# Предсказанная стоимость: 10.171169 , правильная стоимость: 166.37009 разница:  156.19892071899415
# Предсказанная стоимость: 75.6268 , правильная стоимость: 13.970007999999998 разница:  61.656792537109375
# Предсказанная стоимость: 29.631124 , правильная стоимость: 2.0320009999999997 разница:  27.59912349645996
# Предсказанная стоимость: 9.134363 , правильная стоимость: 0.25400013 разница:  8.880363044438477
# Предсказанная стоимость: 53.15554 , правильная стоимость: 1.2700007 разница:  51.8855397663086
# Предсказанная стоимость: 15.896882 , правильная стоимость: 0.50800025 разница:  15.388881807189941
# Предсказанная стоимость: 9.705368 , правильная стоимость: 13.208007 разница:  3.5026389580078128
# Предсказанная стоимость: 31.599886 , правильная стоимость: 14.000007 разница:  17.599878940551758
# Предсказанная стоимость: 9.319518 , правильная стоимость: 0.50800025 разница:  8.811517839294433
# Предсказанная стоимость: 8.389754 , правильная стоимость: 0.25400013 разница:  8.135754165349121
# Предсказанная стоимость: 13.603977 , правильная стоимость: 2.0320009999999997 разница:  11.571976203369141
# Предсказанная стоимость: 10.474513 , правильная стоимость: 0.50800025 разница:  9.966512803894043
# Предсказанная стоимость: 13.871136 , правильная стоимость: 5.080003 разница:  8.791132711669922
# Предсказанная стоимость: 29.891603 , правильная стоимость: 1.5240008 разница:  28.367602669848633
# Предсказанная стоимость: 13.354252 , правильная стоимость: 0.25400013 разница:  13.100251731572266
# Предсказанная стоимость: 14.319813 , правильная стоимость: 1.0160004999999999 разница:  13.303812274658203
# Предсказанная стоимость: 4.2069764 , правильная стоимость: 0.7620004 разница:  3.444976013726807
# Предсказанная стоимость: 6.8453093 , правильная стоимость: 43.434020000000004 разница:  36.58871074249268
# Предсказанная стоимость: 8.378353 , правильная стоимость: 4.572002400000001 разница:  3.806350718896484
# Предсказанная стоимость: 10.8106365 , правильная стоимость: 0.25400013 разница:  10.556636390385743
# Предсказанная стоимость: 53.001633 , правильная стоимость: 10.414006 разница:  42.58762669042969
# Предсказанная стоимость: 10.00905 , правильная стоимость: 0.25400013 разница:  9.755050239262696
# Предсказанная стоимость: 3.9919538 , правильная стоимость: 0.25400013 разница:  3.7379537197924804
# Предсказанная стоимость: 46.817238 , правильная стоимость: 7.366003999999999 разница:  39.45123385400391
# Предсказанная стоимость: 78.06592 , правильная стоимость: 1.2700007 разница:  76.79591726875
# Предсказанная стоимость: 65.245544 , правильная стоимость: 12.446007 разница:  52.79953743359375
# Предсказанная стоимость: 6.2018795 , правильная стоимость: 3.556002 разница:  2.6458775013427736
# Предсказанная стоимость: 17.183775 , правильная стоимость: 11.938006 разница:  5.2457689481201175
# Предсказанная стоимость: 14.966192 , правильная стоимость: 10.668006 разница:  4.298186245483398
# Предсказанная стоимость: 5.5866156 , правильная стоимость: 0.25400013 разница:  5.332615432438965
# Предсказанная стоимость: 5.4069786 , правильная стоимость: 17.78001 разница:  12.373031392822266
# Предсказанная стоимость: 27.634295 , правильная стоимость: 2.5400014 разница:  25.094293109887694
# Предсказанная стоимость: 19.343128 , правильная стоимость: 0.25400013 разница:  19.0891280743457
# Предсказанная стоимость: 16.820309 , правильная стоимость: 1.2700007 разница:  15.550307985302734
# Предсказанная стоимость: 40.990326 , правильная стоимость: 10.922006 разница:  30.068319927734375
# Предсказанная стоимость: 17.769075 , правильная стоимость: 0.25400013 разница:  17.515075263676756
# Предсказанная стоимость: 61.80258 , правильная стоимость: 1.0160004999999999 разница:  60.78658128710938
# Предсказанная стоимость: 21.753918 , правильная стоимость: 43.000023 разница:  21.246105305908202
# Предсказанная стоимость: 7.0411186 , правильная стоимость: 0.25400013 разница:  6.787118491826172
# Предсказанная стоимость: 12.280981 , правильная стоимость: 5.5880027000000005 разница:  6.692978363842773
# Предсказанная стоимость: 16.613655 , правильная стоимость: 1.778001 разница:  14.835654090332032
# Предсказанная стоимость: 5.1032796 , правильная стоимость: 6.6040034 разница:  1.5007238093933104
# Предсказанная стоимость: 80.86945 , правильная стоимость: 0.50800025 разница:  80.36145318017579
# Предсказанная стоимость: 19.420637 , правильная стоимость: 1.778001 разница:  17.642636130737305
# Предсказанная стоимость: 2.1259255 , правильная стоимость: 0.25400013 разница:  1.8719254109240722
# Предсказанная стоимость: 53.767822 , правильная стоимость: 0.7620004 разница:  53.005821865625
# Предсказанная стоимость: 17.136341 , правильная стоимость: 1.5240008 разница:  15.612340294970704
# Предсказанная стоимость: 37.93387 , правильная стоимость: 21.336012 разница:  16.597856408203125
# Предсказанная стоимость: 5.0466404 , правильная стоимость: 1.2700007 разница:  3.7766396961181643
# Предсказанная стоимость: 12.205398 , правильная стоимость: 0.25400013 разница:  11.951397475895996
# Предсказанная стоимость: 9.860496 , правильная стоимость: 0.25400013 разница:  9.606495437321778
# Предсказанная стоимость: 16.295986 , правильная стоимость: 0.25400013 разница:  16.041986045537108
# Предсказанная стоимость: 12.2588825 , правильная стоимость: 0.50800025 разница:  11.750882272583008
# Предсказанная стоимость: 7.9782944 , правильная стоимость: 2.7940012999999997 разница:  5.184293072558594
# Предсказанная стоимость: 10.434725 , правильная стоимость: 0.25400013 разница:  10.180724677739258
# Предсказанная стоимость: 10.309214 , правильная стоимость: 11.430006 разница:  1.1207923616943365
# Предсказанная стоимость: 8.592416 , правильная стоимость: 2.0320009999999997 разница:  6.560414809631348
# Предсказанная стоимость: 17.324919 , правильная стоимость: 0.25400013 разница:  17.07091861694824
# Предсказанная стоимость: 16.4477 , правильная стоимость: 1.0160004999999999 разница:  15.43170000048828
# Предсказанная стоимость: 8.134228 , правильная стоимость: 7.620004 разница:  0.5142237526855471
# Предсказанная стоимость: 10.334339 , правильная стоимость: 1.778001 разница:  8.556338141845703
# Предсказанная стоимость: 5.29602 , правильная стоимость: 22.67501 разница:  17.37898996902466
# Предсказанная стоимость: 6.935482 , правильная стоимость: 11.176005 разница:  4.240522974853516
# Предсказанная стоимость: 22.91181 , правильная стоимость: 0.50800025 разница:  22.40380967126465
# Предсказанная стоимость: 13.526264 , правильная стоимость: 0.11000006 разница:  13.416264130673827
# Предсказанная стоимость: 8.117302 , правильная стоимость: 100.00005 разница:  91.88274805908203
# Предсказанная стоимость: 18.244713 , правильная стоимость: 1.778001 разница:  16.466711829589844
# Предсказанная стоимость: 6.072503 , правильная стоимость: 0.010000005 разница:  6.062503084904785
# Предсказанная стоимость: 15.298443 , правильная стоимость: 20.066011 разница:  4.767568159423828
# Предсказанная стоимость: 8.2486515 , правильная стоимость: 1.0160004999999999 разница:  7.232651004516602
# Предсказанная стоимость: 36.137016 , правильная стоимость: 5.334003 разница:  30.80301329638672
# Предсказанная стоимость: 10.547945 , правильная стоимость: 0.7620004 разница:  9.785944622583008
# Предсказанная стоимость: 7.1449385 , правильная стоимость: 43.000023 разница:  35.85508453106689
# Предсказанная стоимость: 32.64222 , правильная стоимость: 1.0160004999999999 разница:  31.62621904345703
# Предсказанная стоимость: 14.349879 , правильная стоимость: 0.25400013 разница:  14.095879134831543
# Предсказанная стоимость: 40.541588 , правильная стоимость: 0.25400013 разница:  40.28758769958984
# Предсказанная стоимость: 7.7795925 , правильная стоимость: 3.556002 разница:  4.2235905140380865
# Предсказанная стоимость: 11.905516 , правильная стоимость: 0.25400013 разница:  11.651515540776368
# Предсказанная стоимость: 19.919493 , правильная стоимость: 6.3500037 разница:  13.569489021557617
# Предсказанная стоимость: 15.479111 , правильная стоимость: 0.25400013 разница:  15.225110587773438
# Предсказанная стоимость: 11.588826 , правильная стоимость: 6.6040034 разница:  4.984822779504395
# Предсказанная стоимость: 5.9246235 , правильная стоимость: 4.8260026 разница:  1.098620889379883
# Предсказанная стоимость: 19.86175 , правильная стоимость: 0.14000008 разница:  19.72174956904785
# Предсказанная стоимость: 12.813693 , правильная стоимость: 0.25400013 разница:  12.559692916569825
# Предсказанная стоимость: 16.914309 , правильная стоимость: 1.778001 разница:  15.136307547973633
# Предсказанная стоимость: 43.09606 , правильная стоимость: 7.8740044000000005 разница:  35.222057306542965
# Предсказанная стоимость: 4.9523892 , правильная стоимость: 0.50800025 разница:  4.444388990264892
# Предсказанная стоимость: 8.7645235 , правильная стоимость: 0.50800025 разница:  8.25652325616455
# Предсказанная стоимость: 8.515609 , правильная стоимость: 13.970007999999998 разница:  5.454399212463377
# Предсказанная стоимость: 4.9428945 , правильная стоимость: 1.5240008 разница:  3.418893658770752
# Предсказанная стоимость: 13.294142 , правильная стоимость: 13.716007999999999 разница:  0.42186623059081896
# Предсказанная стоимость: 35.590652 , правильная стоимость: 0.030000018 разница:  35.56065244782031
# Предсказанная стоимость: 57.4757 , правильная стоимость: 0.25400013 разница:  57.22170024841797
# Предсказанная стоимость: 7.692582 , правильная стоимость: 14.000007 разница:  6.307424869567871
# Предсказанная стоимость: 11.538909 , правильная стоимость: 1.2700007 разница:  10.268908258435058
# Предсказанная стоимость: 8.034054 , правильная стоимость: 5.334003 разница:  2.7000508024902343
# Предсказанная стоимость: 54.31595 , правильная стоимость: 0.25400013 разница:  54.061948356328124
# Предсказанная стоимость: 39.053146 , правильная стоимость: 0.50800025 разница:  38.545146112304685
# Предсказанная стоимость: 26.76116 , правильная стоимость: 1.0160004999999999 разница:  25.745159396850585
# Предсказанная стоимость: 17.084482 , правильная стоимость: 0.25400013 разница:  16.830482062993163
# Предсказанная стоимость: 68.40957 , правильная стоимость: 0.25400013 разница:  68.1555686566211
# Предсказанная стоимость: 9.945841 , правильная стоимость: 0.17000009 разница:  9.775840745571289
# Предсказанная стоимость: 5.7467246 , правильная стоимость: 0.50800025 разница:  5.2387243555603025
# Предсказанная стоимость: 49.264336 , правильная стоимость: 0.010000005 разница:  49.25433562732422
# Предсказанная стоимость: 45.245407 , правильная стоимость: 6.6040034 разница:  38.64140370449219
# Предсказанная стоимость: 19.875195 , правильная стоимость: 0.25400013 разница:  19.621194419560545
# Предсказанная стоимость: 49.61197 , правильная стоимость: 14.000007 разница:  35.61196199414063
# Предсказанная стоимость: 29.833698 , правильная стоимость: 4.318002 разница:  25.51569627270508
# Предсказанная стоимость: 7.6562796 , правильная стоимость: 0.25400013 разница:  7.402279433903809
# Предсказанная стоимость: 5.441506 , правильная стоимость: 2.2860012000000003 разница:  3.155504708966064
# Предсказанная стоимость: 11.560133 , правильная стоимость: 3.0480015 разница:  8.51213148034668
# Предсказанная стоимость: 10.272985 , правильная стоимость: 4.0640019999999994 разница:  6.208983458374024
# Предсказанная стоимость: 16.495544 , правильная стоимость: 2.5400014 разница:  13.95554303359375
# Предсказанная стоимость: 12.788745 , правильная стоимость: 0.50800025 разница:  12.280744676452636
# Предсказанная стоимость: 19.902828 , правильная стоимость: 3.0480015 разница:  16.854826716552736
# Предсказанная стоимость: 39.642067 , правильная стоимость: 2.5400014 разница:  37.102065555566405
# Предсказанная стоимость: 16.289743 , правильная стоимость: 0.010000005 разница:  16.279743418461916
# Предсказанная стоимость: 35.072243 , правильная стоимость: 2.7940012999999997 разница:  32.27824143681641
# Предсказанная стоимость: 7.4268804 , правильная стоимость: 0.50800025 разница:  6.918880109649658
# Предсказанная стоимость: 17.25786 , правильная стоимость: 4.572002400000001 разница:  12.68585778371582
# Предсказанная стоимость: 21.08588 , правильная стоимость: 6.6040034 разница:  14.481876879541016
# Предсказанная стоимость: 17.549978 , правильная стоимость: 5.5880027000000005 разница:  11.961975556225585
# Предсказанная стоимость: 4.1811705 , правильная стоимость: 0.25400013 разница:  3.9271703335620116
# Предсказанная стоимость: 14.581842 , правильная стоимость: 1.2700007 разница:  13.311841722485351
# Предсказанная стоимость: 10.4051695 , правильная стоимость: 0.1800001 разница:  10.22516938699951
# Предсказанная стоимость: 15.816788 , правильная стоимость: 0.25400013 разница:  15.562787589726563
# Предсказанная стоимость: 17.241812 , правильная стоимость: 0.50800025 разница:  16.733811502319337
# Предсказанная стоимость: 28.429693 , правильная стоимость: 0.50800025 разница:  27.9216929720459
# Предсказанная стоимость: 66.33812 , правильная стоимость: 14.732007999999999 разница:  51.60611150683594
# Предсказанная стоимость: 21.047482 , правильная стоимость: 7.112004 разница:  13.935477536865235
# Предсказанная стоимость: 15.424097 , правильная стоимость: 0.25400013 разница:  15.170096931157227
# Предсказанная стоимость: 15.196434 , правильная стоимость: 0.25400013 разница:  14.942433890996094
# Предсказанная стоимость: 13.502136 , правильная стоимость: 1.5240008 разница:  11.97813543046875
# Предсказанная стоимость: 14.846758 , правильная стоимость: 9.652005 разница:  5.1947528887939445
# Предсказанная стоимость: 8.785467 , правильная стоимость: 1.2700007 разница:  7.515466447827149
# Предсказанная стоимость: 49.1341 , правильная стоимость: 24.892014 разница:  24.24208786767578
# Предсказанная стоимость: 53.63523 , правильная стоимость: 1.0160004999999999 разница:  52.61923051806641
# Предсказанная стоимость: 11.071247 , правильная стоимость: 1.5240008 разница:  9.547246300830079
# Предсказанная стоимость: 13.4286 , правильная стоимость: 1.2700007 разница:  12.158599611279296
# Предсказанная стоимость: 51.738594 , правильная стоимость: 2.5400014 разница:  49.19859265517578
# Предсказанная стоимость: 16.76158 , правильная стоимость: 0.50800025 разница:  16.253579263549806
# Предсказанная стоимость: 6.639131 , правильная стоимость: 0.7620004 разница:  5.87713066918335
# Предсказанная стоимость: 6.627199 , правильная стоимость: 1.778001 разница:  4.849198172973633
# Предсказанная стоимость: 13.117563 , правильная стоимость: 0.50800025 разница:  12.609562997680664
# Предсказанная стоимость: 8.421706 , правильная стоимость: 2.7940012999999997 разница:  5.627704899645996
# Предсказанная стоимость: 18.611397 , правильная стоимость: 0.14000008 разница:  18.47139670955078
# Предсказанная стоимость: 61.605865 , правильная стоимость: 0.25400013 разница:  61.351865348515624
# Предсказанная стоимость: 8.550056 , правильная стоимость: 7.8740044000000005 разница:  0.6760520575195308
# Предсказанная стоимость: 11.7455635 , правильная стоимость: 2.5400014 разница:  9.205562107080079
# Предсказанная стоимость: 8.100378 , правильная стоимость: 0.010000005 разница:  8.090378031499023
# Предсказанная стоимость: 12.088615 , правильная стоимость: 28.000013 разница:  15.91139758251953
# Предсказанная стоимость: 10.827372 , правильная стоимость: 5.334003 разница:  5.493368597290039
# Предсказанная стоимость: 6.672523 , правильная стоимость: 6.6040034 разница:  0.06851962169799819
# Предсказанная стоимость: 15.827899 , правильная стоимость: 5.842003 разница:  9.985895979187012
# Предсказанная стоимость: 53.765358 , правильная стоимость: 2.0320009999999997 разница:  51.733356971191405
# Предсказанная стоимость: 16.18362 , правильная стоимость: 2.7940012999999997 разница:  13.38961915288086
# Предсказанная стоимость: 15.423372 , правильная стоимость: 0.25400013 разница:  15.169372138676758
# Предсказанная стоимость: 6.997897 , правильная стоимость: 9.906006 разница:  2.9081088518676754
# Предсказанная стоимость: 6.111577 , правильная стоимость: 1.0160004999999999 разница:  5.095576533996582
# Предсказанная стоимость: 21.901726 , правильная стоимость: 0.50800025 разница:  21.39372551904297
# Предсказанная стоимость: 9.275892 , правильная стоимость: 1.0160004999999999 разница:  8.25989175769043
# Предсказанная стоимость: 6.5762987 , правильная стоимость: 0.25400013 разница:  6.322298583684082
# Предсказанная стоимость: 5.8801622 , правильная стоимость: 0.7620004 разница:  5.118161839074707
# Предсказанная стоимость: 4.6387825 , правильная стоимость: 0.010000005 разница:  4.628782496220703
# Предсказанная стоимость: 15.397485 , правильная стоимость: 0.25400013 разница:  15.14348464935791
# Предсказанная стоимость: 27.275244 , правильная стоимость: 2.7940012999999997 разница:  24.481242459155276
# Предсказанная стоимость: 15.317945 , правильная стоимость: 3.3020017 разница:  12.015942826672363
# Предсказанная стоимость: 15.653789 , правильная стоимость: 3.810002 разница:  11.843786566589355
# Предсказанная стоимость: 65.69675 , правильная стоимость: 1.2700007 разница:  64.42674612617188
# Предсказанная стоимость: 5.581147 , правильная стоимость: 1.778001 разница:  3.8031461939086917
# Предсказанная стоимость: 39.05314 , правильная стоимость: 0.50800025 разница:  38.545138482910154
# Предсказанная стоимость: 3.754149 , правильная стоимость: 0.25400013 разница:  3.5001488301135253
# Предсказанная стоимость: 9.640256 , правильная стоимость: 1.2700007 разница:  8.37025522803955
# Предсказанная стоимость: 9.971165 , правильная стоимость: 3.3020017 разница:  6.669163003369141
# Предсказанная стоимость: 6.3889284 , правильная стоимость: 0.25400013 разница:  6.134928283391114
# Предсказанная стоимость: 170.18138 , правильная стоимость: 3.556002 разница:  166.62537922558593
# Предсказанная стоимость: 15.847343 , правильная стоимость: 20.066011 разница:  4.218667555175781
# Предсказанная стоимость: 16.251442 , правильная стоимость: 0.25400013 разница:  15.997441825566407
# Предсказанная стоимость: 15.483133 , правильная стоимость: 14.000007 разница:  1.483126316040039
# Предсказанная стоимость: 3.239063 , правильная стоимость: 1.778001 разница:  1.461062024520874
# Предсказанная стоимость: 8.340506 , правильная стоимость: 2.0320009999999997 разница:  6.308504599975587
# Предсказанная стоимость: 10.696365 , правильная стоимость: 1.0160004999999999 разница:  9.680364856445312
# Предсказанная стоимость: 11.701059 , правильная стоимость: 1.2700007 разница:  10.431058641430663
# Предсказанная стоимость: 14.684025 , правильная стоимость: 2.2860012000000003 разница:  12.398023610791014
# Предсказанная стоимость: 11.044481 , правильная стоимость: 0.7620004 разница:  10.28248087746582
# Предсказанная стоимость: 44.300003 , правильная стоимость: 0.50800025 разница:  43.79200280175781
# Предсказанная стоимость: 9.3797035 , правильная стоимость: 0.02000001 разница:  9.359703511728515
# Предсказанная стоимость: 60.26593 , правильная стоимость: 2.0320009999999997 разница:  58.23392917578125
# Предсказанная стоимость: 36.46412 , правильная стоимость: 5.425003 разница:  31.03911595751953
# Предсказанная стоимость: 4.181159 , правильная стоимость: 2.2860012000000003 разница:  1.8951578194702146
# Предсказанная стоимость: 11.825722 , правильная стоимость: 2.0320009999999997 разница:  9.793720740722657
# Предсказанная стоимость: 20.851473 , правильная стоимость: 0.25400013 разница:  20.597472724614256
# Предсказанная стоимость: 12.976883 , правильная стоимость: 4.0640019999999994 разница:  8.912880934570314
# Предсказанная стоимость: 9.060566 , правильная стоимость: 3.556002 разница:  5.504563948486329
# Предсказанная стоимость: 6.3962297 , правильная стоимость: 4.8260026 разница:  1.5702271439575197
# Предсказанная стоимость: 5.87259 , правильная стоимость: 0.25400013 разница:  5.618589935002442
# Предсказанная стоимость: 9.057764 , правильная стоимость: 0.25400013 разница:  8.803763923344727
# Предсказанная стоимость: 94.21234 , правильная стоимость: 0.25400013 разница:  93.95834117859376
# Предсказанная стоимость: 20.539898 , правильная стоимость: 7.366003999999999 разница:  13.173893918701172
# Предсказанная стоимость: 8.328367 , правильная стоимость: 0.25400013 разница:  8.074367103276368
# Предсказанная стоимость: 25.92259 , правильная стоимость: 1.0160004999999999 разница:  24.906589755737304
# Предсказанная стоимость: 17.12338 , правильная стоимость: 2.2860012000000003 разница:  14.837379461010741
# Предсказанная стоимость: 66.32876 , правильная стоимость: 0.010000005 разница:  66.3187582347461
# Предсказанная стоимость: 12.621945 , правильная стоимость: 0.25400013 разница:  12.367945251164551
# Предсказанная стоимость: 6.345464 , правильная стоимость: 1.778001 разница:  4.5674632295837405
# Предсказанная стоимость: 6.186549 , правильная стоимость: 1.778001 разница:  4.408548186706543
# Предсказанная стоимость: 8.627427 , правильная стоимость: 0.50800025 разница:  8.119426851135254
# Предсказанная стоимость: 9.145254 , правильная стоимость: 1.2700007 разница:  7.875253435131836
# Предсказанная стоимость: 23.086256 , правильная стоимость: 4.318002 разница:  18.76825402722168
# Предсказанная стоимость: 16.444658 , правильная стоимость: 2.5400014 разница:  13.904656879418946
# Предсказанная стоимость: 15.04968 , правильная стоимость: 0.02000001 разница:  15.02967974616455
# Предсказанная стоимость: 14.705914 , правильная стоимость: 0.25400013 разница:  14.451913413701172
# Предсказанная стоимость: 15.940327 , правильная стоимость: 10.160006 разница:  5.780320690673829
# Предсказанная стоимость: 5.255485 , правильная стоимость: 1.0160004999999999 разница:  4.239484557830811
# Предсказанная стоимость: 17.743153 , правильная стоимость: 12.446007 разница:  5.297145618408203
# Предсказанная стоимость: 9.033769 , правильная стоимость: 3.3020017 разница:  5.731766953869629
# Предсказанная стоимость: 10.148151 , правильная стоимость: 0.04000002 разница:  10.108151377705077
# Предсказанная стоимость: 8.552089 , правильная стоимость: 6.3500037 разница:  2.2020850374877927
# Предсказанная стоимость: 14.902582 , правильная стоимость: 1.0160004999999999 разница:  13.886581668579101
# Предсказанная стоимость: 4.688781 , правильная стоимость: 1.2700007 разница:  3.418780084606934
# Предсказанная стоимость: 17.79667 , правильная стоимость: 1.2700007 разница:  16.52667021369629
# Предсказанная стоимость: 7.711522 , правильная стоимость: 0.25400013 разница:  7.457521972355957
# Предсказанная стоимость: 12.11429 , правильная стоимость: 1.778001 разница:  10.336289237426758
# Предсказанная стоимость: 13.819218 , правильная стоимость: 9.652005 разница:  4.167212681884765
# Предсказанная стоимость: 34.29232 , правильная стоимость: 17.272009 разница:  17.020311251464843
# Предсказанная стоимость: 20.388502 , правильная стоимость: 0.7620004 разница:  19.626501720971678
# Предсказанная стоимость: 10.196685 , правильная стоимость: 0.25400013 разница:  9.942684707341309
# Предсказанная стоимость: 7.767855 , правильная стоимость: 1.0160004999999999 разница:  6.751854667388916
# Предсказанная стоимость: 52.706406 , правильная стоимость: 0.50800025 разница:  52.198405389648435
# Предсказанная стоимость: 13.836468 , правильная стоимость: 7.366003999999999 разница:  6.4704637429199225
# Предсказанная стоимость: 18.289156 , правильная стоимость: 1.5240008 разница:  16.765155160083008
# Предсказанная стоимость: 16.841757 , правильная стоимость: 0.50800025 разница:  16.333756570678712
# Предсказанная стоимость: 14.226025 , правильная стоимость: 3.0480015 разница:  11.178023127685547
# Предсказанная стоимость: 5.292824 , правильная стоимость: 0.7620004 разница:  4.5308233915039064
# Предсказанная стоимость: 7.425209 , правильная стоимость: 1.0160004999999999 разница:  6.409208545410157
# Предсказанная стоимость: 93.24692 , правильная стоимость: 0.25400013 разница:  92.99291759460938
# Предсказанная стоимость: 10.173925 , правильная стоимость: 0.25400013 разница:  9.919925269780274
# Предсказанная стоимость: 7.938055 , правильная стоимость: 1.0160004999999999 разница:  6.922054538452149
# Предсказанная стоимость: 12.257888 , правильная стоимость: 0.25400013 разница:  12.003887710270996
# Предсказанная стоимость: 5.8229938 , правильная стоимость: 0.25400013 разница:  5.5689936253405765
# Предсказанная стоимость: 13.079546 , правильная стоимость: 13.208007 разница:  0.12846102526855496
# Предсказанная стоимость: 20.008072 , правильная стоимость: 14.732007999999999 разница:  5.276063899414064
# Предсказанная стоимость: 12.558727 , правильная стоимость: 2.5400014 разница:  10.018725864404297
# Предсказанная стоимость: 22.644514 , правильная стоимость: 4.0640019999999994 разница:  18.580512083862306
# Предсказанная стоимость: 15.2309065 , правильная стоимость: 719.9993 разница:  704.7683935134887
# Предсказанная стоимость: 8.183293 , правильная стоимость: 16.002008 разница:  7.818714657409668
# Предсказанная стоимость: 5.794753 , правильная стоимость: 3.3020017 разница:  2.492751374645996
# Предсказанная стоимость: 24.346048 , правильная стоимость: 0.25400013 разница:  24.092048225102538
# Предсказанная стоимость: 28.205765 , правильная стоимость: 0.50800025 разница:  27.697764520507814
# Предсказанная стоимость: 13.9688225 , правильная стоимость: 0.010000005 разница:  13.958822474248047
# Предсказанная стоимость: 11.270006 , правильная стоимость: 1.0160004999999999 разница:  10.25400567980957
# Предсказанная стоимость: 8.026882 , правильная стоимость: 0.25400013 разница:  7.77288204163086
# Предсказанная стоимость: 6.8870583 , правильная стоимость: 1.778001 разница:  5.109057258056641
# Предсказанная стоимость: 14.654503 , правильная стоимость: 1.0160004999999999 разница:  13.638502368652343
# Предсказанная стоимость: 25.681719 , правильная стоимость: 22.860012 разница:  2.821706826293944
# Предсказанная стоимость: 19.620016 , правильная стоимость: 1.0160004999999999 разница:  18.60401559802246
# Предсказанная стоимость: 5.387682 , правильная стоимость: 0.50800025 разница:  4.87968171105957
# Предсказанная стоимость: 4.975621 , правильная стоимость: 0.25400013 разница:  4.721621093449707
# Предсказанная стоимость: 8.8863735 , правильная стоимость: 2.0320009999999997 разница:  6.854372519897462
# Предсказанная стоимость: 59.95278 , правильная стоимость: 6.6040034 разница:  53.3487782772461
# Предсказанная стоимость: 9.109074 , правильная стоимость: 0.25400013 разница:  8.855073508916016
# Предсказанная стоимость: 7.833215 , правильная стоимость: 0.25400013 разница:  7.579215106663819
# Предсказанная стоимость: 5.9709916 , правильная стоимость: 0.50800025 разница:  5.462991361480713
# Предсказанная стоимость: 5.146889 , правильная стоимость: 0.25400013 разница:  4.892889079747315
# Предсказанная стоимость: 25.590815 , правильная стоимость: 1.778001 разница:  23.812813590454102
# Предсказанная стоимость: 11.267897 , правильная стоимость: 2.0320009999999997 разница:  9.23589565222168
# Предсказанная стоимость: 5.5047936 , правильная стоимость: 0.50800025 разница:  4.996793393951416
# Предсказанная стоимость: 164.84792 , правильная стоимость: 1106.4246 разница:  941.576684350586
# Предсказанная стоимость: 159.01491 , правильная стоимость: 7.112004 разница:  151.90290383691405
# Предсказанная стоимость: 13.716224 , правильная стоимость: 2.7940012999999997 разница:  10.92222241673584
# Предсказанная стоимость: 5.0537148 , правильная стоимость: 2.0320009999999997 разница:  3.021713752197266
# Предсказанная стоимость: 6.089904 , правильная стоимость: 1.5240008 разница:  4.565903031481934
# Предсказанная стоимость: 123.50312 , правильная стоимость: 0.25400013 разница:  123.24912029236329
# Предсказанная стоимость: 106.97386 , правильная стоимость: 1.5240008 разница:  105.44986089433594
# Предсказанная стоимость: 8.31657 , правильная стоимость: 0.25400013 разница:  8.062570151982422
# Предсказанная стоимость: 8.122644 , правильная стоимость: 2.5400014 разница:  5.582643024438477
# Предсказанная стоимость: 5.854441 , правильная стоимость: 0.50800025 разница:  5.346440915924072
# Предсказанная стоимость: 6.170418 , правильная стоимость: 5.080003 разница:  1.0904147856445316
# Предсказанная стоимость: 7.9938354 , правильная стоимость: 20.320010999999997 разница:  12.326175550781247
# Предсказанная стоимость: 62.16352 , правильная стоимость: 86.000046 разница:  23.836525187011716
# Предсказанная стоимость: 17.436068 , правильная стоимость: 1.778001 разница:  15.658066581176758
# Предсказанная стоимость: 6.9877267 , правильная стоимость: 2.0320009999999997 разница:  4.9557256883850105
# Предсказанная стоимость: 10.673486 , правильная стоимость: 5.080003 разница:  5.5934827559204106
# Предсказанная стоимость: 0.1425643 , правильная стоимость: 0.25400013 разница:  0.11143583327758788
# Предсказанная стоимость: 7.194606 , правильная стоимость: 2.5400014 разница:  4.6546044273315434
# Предсказанная стоимость: 16.347645 , правильная стоимость: 0.50800025 разница:  15.839644555908203
# Предсказанная стоимость: 17.105427 , правильная стоимость: 9.144005 разница:  7.961421788330078
# Предсказанная стоимость: 152.30536 , правильная стоимость: 3.3020017 разница:  149.00335718671874
# Предсказанная стоимость: 10.888491 , правильная стоимость: 0.7200004 разница:  10.168490276879883
# Предсказанная стоимость: 5.331854 , правильная стоимость: 3.556002 разница:  1.7758518665771486
# Предсказанная стоимость: 22.551662 , правильная стоимость: 0.25400013 разница:  22.297662315068358
# Предсказанная стоимость: 6.156266 , правильная стоимость: 1.0160004999999999 разница:  5.140265712463379
# Предсказанная стоимость: 18.452742 , правильная стоимость: 25.550014 разница:  7.097272377075196
# Предсказанная стоимость: 17.249334 , правильная стоимость: 5.842003 разница:  11.407331335327148
# Предсказанная стоимость: 16.653677 , правильная стоимость: 0.25400013 разница:  16.399676856694335
# Предсказанная стоимость: 13.592545 , правильная стоимость: 3.3020017 разница:  10.290542855664063
# Предсказанная стоимость: 33.93342 , правильная стоимость: 1.5240008 разница:  32.40941747392578
# Предсказанная стоимость: 43.351746 , правильная стоимость: 1.0160004999999999 разница:  42.33574510546875
# Предсказанная стоимость: 7.8886585 , правильная стоимость: 0.50800025 разница:  7.38065827355957
# Предсказанная стоимость: 12.759348 , правильная стоимость: 2.5400014 разница:  10.219346515649415
# Предсказанная стоимость: 37.30021 , правильная стоимость: 0.25400013 разница:  37.046208915410155
# Предсказанная стоимость: 6.148494 , правильная стоимость: 2.5400014 разница:  3.608492366784668
# Предсказанная стоимость: 9.559213 , правильная стоимость: 0.010000005 разница:  9.549212679631347
# Предсказанная стоимость: 13.213654 , правильная стоимость: 0.02000001 разница:  13.193653554453125
# Предсказанная стоимость: 75.05026 , правильная стоимость: 6.858003999999999 разница:  68.19225845117188
# Предсказанная стоимость: 8.127331 , правильная стоимость: 1.778001 разница:  6.349329780029297
# Предсказанная стоимость: 17.067707 , правильная стоимость: 0.25400013 разница:  16.813706931767577
# Предсказанная стоимость: 30.454288 , правильная стоимость: 1.0160004999999999 разница:  29.438287982666015
# Предсказанная стоимость: 17.63791 , правильная стоимость: 0.010000005 разница:  17.62791083789551
# Предсказанная стоимость: 11.241082 , правильная стоимость: 1.5240008 разница:  9.717081391467286
# Предсказанная стоимость: 86.86505 , правильная стоимость: 1.2700007 разница:  85.59505056953125
# Предсказанная стоимость: 49.140396 , правильная стоимость: 0.25400013 разница:  48.88639598816406
# Предсказанная стоимость: 9.996349 , правильная стоимость: 0.7620004 разница:  9.234348934716797
# Предсказанная стоимость: 19.872736 , правильная стоимость: 0.50800025 разница:  19.364735727172853
# Предсказанная стоимость: 5.3337517 , правильная стоимость: 0.15000008 разница:  5.183751598466797
# Предсказанная стоимость: 17.893887 , правильная стоимость: 5.080003 разница:  12.81388356616211
# Предсказанная стоимость: 147.40346 , правильная стоимость: 0.25400013 разница:  147.14945751160155
# Предсказанная стоимость: 28.656315 , правильная стоимость: 0.35000017 разница:  28.306314679853514
# Предсказанная стоимость: 28.474743 , правильная стоимость: 7.112004 разница:  21.362738889404298
# Предсказанная стоимость: 30.659452 , правильная стоимость: 6.858003999999999 разница:  23.80144843835449
# Предсказанная стоимость: 11.397377 , правильная стоимость: 1.5240008 разница:  9.873376214160157
# Предсказанная стоимость: 16.438658 , правильная стоимость: 4.8260026 разница:  11.612655160620118
# Предсказанная стоимость: 24.31778 , правильная стоимость: 14.000007 разница:  10.317772541015625
# Предсказанная стоимость: 12.09737 , правильная стоимость: 3.6000019999999995 разница:  8.497368147705078
# Предсказанная стоимость: 11.381741 , правильная стоимость: 1.5240008 разница:  9.85773977006836
# Предсказанная стоимость: 76.34618 , правильная стоимость: 0.50800025 разница:  75.83818352685547
# Предсказанная стоимость: 10.628877 , правильная стоимость: 0.04000002 разница:  10.58887666609619
# Предсказанная стоимость: 26.408728 , правильная стоимость: 2.2860012000000003 разница:  24.122726445874022
# Предсказанная стоимость: 9.545252 , правильная стоимость: 158.00008 разница:  148.45482815368652
# Предсказанная стоимость: 16.824846 , правильная стоимость: 1.778001 разница:  15.046845267700196
# Предсказанная стоимость: 27.140045 , правильная стоимость: 9.906006 разница:  17.234039166015627
# ...
# Предсказанная стоимость: 7.172111 , правильная стоимость: 2.0320009999999997 разница:  5.140110034393311
# Предсказанная стоимость: 9.721804 , правильная стоимость: 4.0640019999999994 разница:  5.657801665161133
# Предсказанная стоимость: 18.989212 , правильная стоимость: 0.25400013 разница:  18.73521190613281
# Предсказанная стоимость: 62.499725 , правильная стоимость: 1.2700007 разница:  61.22972464179688
# Предсказанная стоимость: 54.950912 , правильная стоимость: 0.25400013 разница:  54.696912345585936
# Предсказанная стоимость: 9.850478 , правильная стоимость: 6.858003999999999 разница:  2.9924741723022468
# Предсказанная стоимость: 19.971807 , правильная стоимость: 0.25400013 разница:  19.717807349858397
# Предсказанная стоимость: 5.682866 , правильная стоимость: 2.0320009999999997 разница:  3.6508650964965823
# Предсказанная стоимость: 8.684332 , правильная стоимость: 1.778001 разница:  6.906330893920899
# Предсказанная стоимость: 14.42148 , правильная стоимость: 0.25400013 разница:  14.167480048833008
# Предсказанная стоимость: 10.481504 , правильная стоимость: 0.25400013 разница:  10.227504310307618
# Предсказанная стоимость: 6.311124 , правильная стоимость: 0.70000035 разница:  5.611123497961426
# Предсказанная стоимость: 8.812768 , правильная стоимость: 0.50800025 разница:  8.30476773248291
# Предсказанная стоимость: 59.80919 , правильная стоимость: 0.7620004 разница:  59.04718844277344
# Предсказанная стоимость: 5.8074656 , правильная стоимость: 1.0160004999999999 разница:  4.791465053283692
# Предсказанная стоимость: 56.00383 , правильная стоимость: 1.2700007 разница:  54.73382925605469
# Предсказанная стоимость: 77.472244 , правильная стоимость: 2853.4375 разница:  2775.9652557373047
# Предсказанная стоимость: 37.64247 , правильная стоимость: 5.5880027000000005 разница:  32.05446861347656
# Предсказанная стоимость: 46.997894 , правильная стоимость: 1.2700007 разница:  45.72789358710938
# Предсказанная стоимость: 20.304821 , правильная стоимость: 34.03602 разница:  13.731198985595704
# Предсказанная стоимость: 11.270675 , правильная стоимость: 0.25400013 разница:  11.016674575505371
# Предсказанная стоимость: 12.865208 , правильная стоимость: 9.144005 разница:  3.7212026721191407
# Предсказанная стоимость: 10.946404 , правильная стоимость: 0.25400013 разница:  10.692404327092285
# Предсказанная стоимость: 37.881737 , правильная стоимость: 45.720024 разница:  7.8382872446289085
# Предсказанная стоимость: 8.94002 , правильная стоимость: 0.50800025 разница:  8.432019357543945
# Предсказанная стоимость: 9.513537 , правильная стоимость: 0.25400013 разница:  9.259537276921387
# Предсказанная стоимость: 9.25231 , правильная стоимость: 0.25400013 разница:  8.998309669194336
# Предсказанная стоимость: 10.975264 , правильная стоимость: 1.0160004999999999 разница:  9.959263095581054
# Предсказанная стоимость: 23.127802 , правильная стоимость: 1.2700007 разница:  21.8578011951416
# Предсказанная стоимость: 13.556551 , правильная стоимость: 3.556002 разница:  10.000548979614258
# Предсказанная стоимость: 23.941 , правильная стоимость: 1.0160004999999999 разница:  22.92499948474121
# Предсказанная стоимость: 34.074562 , правильная стоимость: 0.50800025 разница:  33.566561822753904
# Предсказанная стоимость: 8.374287 , правильная стоимость: 3.6000019999999995 разница:  4.774284651611328
# Предсказанная стоимость: 4.501925 , правильная стоимость: 4.572002400000001 разница:  0.07007740839233456
# Предсказанная стоимость: 106.193375 , правильная стоимость: 0.25400013 разница:  105.93937450378907
# Предсказанная стоимость: 6.30802 , правильная стоимость: 0.7620004 разница:  5.546019714898682
# Предсказанная стоимость: 6.5846586 , правильная стоимость: 0.10000005 разница:  6.484658572741699
# Предсказанная стоимость: 8.720981 , правильная стоимость: 2.5400014 разница:  6.180979244226075
# Предсказанная стоимость: 9.307512 , правильная стоимость: 0.010000005 разница:  9.297512278325195
# Предсказанная стоимость: 16.208845 , правильная стоимость: 0.35000017 разница:  15.858844968549805
# Предсказанная стоимость: 16.03749 , правильная стоимость: 6.3500037 разница:  9.687487144726562
# Предсказанная стоимость: 17.14855 , правильная стоимость: 9.652005 разница:  7.496545033569335
# Предсказанная стоимость: 53.001633 , правильная стоимость: 0.25400013 разница:  52.747632560429686
# Предсказанная стоимость: 9.736366 , правильная стоимость: 1.0160004999999999 разница:  8.720365771972656
# Предсказанная стоимость: 11.673924 , правильная стоимость: 0.35000017 разница:  11.323924276105958
# Предсказанная стоимость: 17.707863 , правильная стоимость: 0.25400013 разница:  17.453862724003905
# Предсказанная стоимость: 9.345808 , правильная стоимость: 2.5400014 разница:  6.805806629174805
# Предсказанная стоимость: 7.2112207 , правильная стоимость: 1.2700007 разница:  5.941220041271973
# Предсказанная стоимость: 41.18666 , правильная стоимость: 0.25400013 разница:  40.93266063660156
# Предсказанная стоимость: 6.739272 , правильная стоимость: 0.25400013 разница:  6.485271987614746
# Предсказанная стоимость: 10.320857 , правильная стоимость: 0.25400013 разница:  10.066856918034668
# Предсказанная стоимость: 26.813091 , правильная стоимость: 0.50800025 разница:  26.305091028076173
# Предсказанная стоимость: 11.901817 , правильная стоимость: 13.208007 разница:  1.3061896782226565
# Предсказанная стоимость: 18.569395 , правильная стоимость: 0.7620004 разница:  17.807394665307616
# Предсказанная стоимость: 15.033304 , правильная стоимость: 6.096003 разница:  8.93730121447754
# Предсказанная стоимость: 19.039673 , правильная стоимость: 0.25400013 разница:  18.7856727215625
# Предсказанная стоимость: 22.979284 , правильная стоимость: 0.70000035 разница:  22.279283936499024
# Предсказанная стоимость: 17.104631 , правильная стоимость: 2.2860012000000003 разница:  14.818630223950194
# Предсказанная стоимость: 10.674203 , правильная стоимость: 8.382005 разница:  2.292197919006348
# Предсказанная стоимость: 29.293236 , правильная стоимость: 144.00008 разница:  114.7068442211914
# Предсказанная стоимость: 11.148672 , правильная стоимость: 2.7940012999999997 разница:  8.354670803881836
# Предсказанная стоимость: 12.068642 , правильная стоимость: 4.8260026 разница:  7.242639062597656
# Предсказанная стоимость: 15.514681 , правильная стоимость: 1.2700007 разница:  14.244680162426757
# Предсказанная стоимость: 17.585636 , правильная стоимость: 0.50800025 разница:  17.077635888916017
# Предсказанная стоимость: 6.958885 , правильная стоимость: 2.2860012000000003 разница:  4.6728839928710935
# Предсказанная стоимость: 21.636751 , правильная стоимость: 0.7620004 разница:  20.874750774926756
# Предсказанная стоимость: 17.384047 , правильная стоимость: 0.25400013 разница:  17.13004642456543
# Предсказанная стоимость: 8.841478 , правильная стоимость: 2.0320009999999997 разница:  6.809477347778321
# Предсказанная стоимость: 20.580807 , правильная стоимость: 21.600012 разница:  1.0192052678222652
# Предсказанная стоимость: 10.692108 , правильная стоимость: 4.8260026 разница:  5.866105554296875
# Предсказанная стоимость: 9.91694 , правильная стоимость: 0.6700003000000001 разница:  9.246939435412598
# Предсказанная стоимость: 20.923265 , правильная стоимость: 0.25400013 разница:  20.66926532715332
# Предсказанная стоимость: 29.020454 , правильная стоимость: 1.5240008 разница:  27.49645360673828
# Предсказанная стоимость: 12.892208 , правильная стоимость: 0.25400013 разница:  12.638207969365235
# Предсказанная стоимость: 39.883476 , правильная стоимость: 0.25400013 разница:  39.62947612732422
# Предсказанная стоимость: 10.048376 , правильная стоимость: 0.50800025 разница:  9.540375833374023
# Предсказанная стоимость: 19.282623 , правильная стоимость: 0.7620004 разница:  18.520622891015623
# Предсказанная стоимость: 5.975148 , правильная стоимость: 0.25400013 разница:  5.72114807098877
# Предсказанная стоимость: 5.039295 , правильная стоимость: 0.25400013 разница:  4.7852950665332035
# Предсказанная стоимость: 20.461653 , правильная стоимость: 1.778001 разница:  18.683651755737305
# Предсказанная стоимость: 11.624769 , правильная стоимость: 0.50800025 разница:  11.11676896081543
# Предсказанная стоимость: 8.356121 , правильная стоимость: 0.50800025 разница:  7.848120813232422
# Предсказанная стоимость: 10.827346 , правильная стоимость: 0.25400013 разница:  10.573345718083496
# Предсказанная стоимость: 11.181845 , правильная стоимость: 5.080003 разница:  6.101841711303711
# Предсказанная стоимость: 8.803821 , правильная стоимость: 2.7940012999999997 разница:  6.009819310046387
# Предсказанная стоимость: 13.886732 , правильная стоимость: 2.0320009999999997 разница:  11.85473110144043
# Предсказанная стоимость: 4.3328834 , правильная стоимость: 1.0160004999999999 разница:  3.3168828580017093
# Предсказанная стоимость: 15.03411 , правильная стоимость: 17.78001 разница:  2.7458999307250984
# Предсказанная стоимость: 10.416271 , правильная стоимость: 4.0640019999999994 разница:  6.352269209716797
# Предсказанная стоимость: 5.4017625 , правильная стоимость: 0.7620004 разница:  4.639762085504151
# Предсказанная стоимость: 7.016812 , правильная стоимость: 0.7620004 разница:  6.254811447686768
# Предсказанная стоимость: 10.896526 , правильная стоимость: 12.192006 разница:  1.2954796633300774
# Предсказанная стоимость: 13.071446 , правильная стоимость: 0.030000018 разница:  13.041446400762206
# Предсказанная стоимость: 18.40373 , правильная стоимость: 0.010000005 разница:  18.393730387456056
# Предсказанная стоимость: 9.171471 , правильная стоимость: 8.382005 разница:  0.7894656420898443
# Предсказанная стоимость: 45.55033 , правильная стоимость: 0.50800025 разница:  45.042330865722654
# Предсказанная стоимость: 16.470055 , правильная стоимость: 0.04000002 разница:  16.430054606464843
# Предсказанная стоимость: 24.010553 , правильная стоимость: 0.7620004 разница:  23.24855295998535
# Предсказанная стоимость: 8.966152 , правильная стоимость: 0.25400013 разница:  8.71215206116211
# Предсказанная стоимость: 41.048897 , правильная стоимость: 2.0320009999999997 разница:  39.01689578955078
# Предсказанная стоимость: 27.835943 , правильная стоимость: 12.225006 разница:  15.610937222045898
# Предсказанная стоимость: 11.30958 , правильная стоимость: 2.1500013 разница:  9.159578549243165
# Предсказанная стоимость: 36.23703 , правильная стоимость: 0.25400013 разница:  35.983029899296874
# Предсказанная стоимость: 13.687692 , правильная стоимость: 1.0750006 разница:  12.612691088537598
# Предсказанная стоимость: 16.748753 , правильная стоимость: 3.810002 разница:  12.93875059399414
# Предсказанная стоимость: 8.236775 , правильная стоимость: 4.318002 разница:  3.9187733982543946
# Предсказанная стоимость: 8.626672 , правильная стоимость: 6.858003999999999 разница:  1.7686677910766608
# Предсказанная стоимость: 9.437328 , правильная стоимость: 3.3020017 разница:  6.135326638623047
# Предсказанная стоимость: 32.466904 , правильная стоимость: 0.50800025 разница:  31.95890343652344
# Предсказанная стоимость: 14.363815 , правильная стоимость: 0.25400013 разница:  14.109815177617188
# Предсказанная стоимость: 51.91741 , правильная стоимость: 3.3020017 разница:  48.61541010419922
# Предсказанная стоимость: 21.564077 , правильная стоимость: 0.35000017 разница:  21.214077207319335
# Предсказанная стоимость: 14.159998 , правильная стоимость: 1.778001 разница:  12.381996940063477
# Предсказанная стоимость: 81.11534 , правильная стоимость: 2.7940012999999997 разница:  78.32133988652343
# Предсказанная стоимость: 4.3229127 , правильная стоимость: 2.5400014 разница:  1.7829112930236817
# Предсказанная стоимость: 9.021159 , правильная стоимость: 3.3020017 разница:  5.7191574720581055
# Предсказанная стоимость: 80.18257 , правильная стоимость: 0.50800025 разница:  79.67457116113282
# Предсказанная стоимость: 10.235817 , правильная стоимость: 1.0160004999999999 разница:  9.219816455566406
# Предсказанная стоимость: 9.309013 , правильная стоимость: 1.778001 разница:  7.531012366699219
# Предсказанная стоимость: 35.0148 , правильная стоимость: 1.0160004999999999 разница:  33.99880052539063
# Предсказанная стоимость: 5.868854 , правильная стоимость: 0.25400013 разница:  5.61485391586792
# Предсказанная стоимость: 68.6443 , правильная стоимость: 1.778001 разница:  66.86630136816406
# Предсказанная стоимость: 69.388504 , правильная стоимость: 0.50800025 разница:  68.88050377832032
# Предсказанная стоимость: 6.0343237 , правильная стоимость: 1.0160004999999999 разница:  5.018323192321778
# Предсказанная стоимость: 121.46071 , правильная стоимость: 1.2700007 разница:  120.19070791816407
# Предсказанная стоимость: 9.594766 , правильная стоимость: 0.50800025 разница:  9.086765413146972
# Предсказанная стоимость: 5.609241 , правильная стоимость: 4.572002400000001 разница:  1.0372386087585443
# Предсказанная стоимость: 12.222715 , правильная стоимость: 26.416014 разница:  14.193298622192383
# Предсказанная стоимость: 29.627579 , правильная стоимость: 0.50800025 разница:  29.119578485351564
# Предсказанная стоимость: 3.0390508 , правильная стоимость: 0.25400013 разница:  2.785050687489624
# Предсказанная стоимость: 18.05114 , правильная стоимость: 2.2860012000000003 разница:  15.765138631542968
# Предсказанная стоимость: 15.149233 , правильная стоимость: 4.0640019999999994 разница:  11.085230864379884
# Предсказанная стоимость: 12.518917 , правильная стоимость: 0.7620004 разница:  11.756916683740235
# Предсказанная стоимость: 4.5860043 , правильная стоимость: 0.50800025 разница:  4.078004007202148
# Предсказанная стоимость: 159.81924 , правильная стоимость: 0.7620004 разница:  159.05724398476562
# Предсказанная стоимость: 106.90503 , правильная стоимость: 0.25400013 разница:  106.651029166875
# Предсказанная стоимость: 10.383908 , правильная стоимость: 1.2700007 разница:  9.11390757178955
# Предсказанная стоимость: 11.374367 , правильная стоимость: 5.5880027000000005 разница:  5.786364060253906
# Предсказанная стоимость: 23.622683 , правильная стоимость: 0.25400013 разница:  23.36868244141113
# Предсказанная стоимость: 6.806614 , правильная стоимость: 1.0160004999999999 разница:  5.790613422119141
# Предсказанная стоимость: 17.403128 , правильная стоимость: 1.0160004999999999 разница:  16.387127170288085
# Предсказанная стоимость: 20.00663 , правильная стоимость: 4.0640019999999994 разница:  15.942627943847658
# Предсказанная стоимость: 6.7505856 , правильная стоимость: 0.7620004 разница:  5.988585156030274
# Предсказанная стоимость: 13.819811 , правильная стоимость: 1.0160004999999999 разница:  12.80381036730957
# Предсказанная стоимость: 5.7809644 , правильная стоимость: 1.0160004999999999 разница:  4.764963874542237
# Предсказанная стоимость: 9.88546 , правильная стоимость: 57.000034 разница:  47.114574100097656
# Предсказанная стоимость: 10.957331 , правильная стоимость: 0.25400013 разница:  10.703330573735352
# Предсказанная стоимость: 5.003869 , правильная стоимость: 1.0160004999999999 разница:  3.9878685567016605
# Предсказанная стоимость: 48.294205 , правильная стоимость: 0.02000001 разница:  48.274204701914066
# Предсказанная стоимость: 6.9678597 , правильная стоимость: 1.778001 разница:  5.189858745025635
# Предсказанная стоимость: 10.318273 , правильная стоимость: 0.030000018 разница:  10.288272572637206
# Предсказанная стоимость: 16.421856 , правильная стоимость: 5.080003 разница:  11.341852926513672
# Предсказанная стоимость: 15.192807 , правильная стоимость: 4.0640019999999994 разница:  11.128805197570802
# Предсказанная стоимость: 9.275007 , правильная стоимость: 3.6000019999999995 разница:  5.675005247924805
# Предсказанная стоимость: 13.2136345 , правильная стоимость: 0.50800025 разница:  12.705634240966797
# Предсказанная стоимость: 12.757824 , правильная стоимость: 28.000013 разница:  15.242189055908202
# Предсказанная стоимость: 10.120297 , правильная стоимость: 7.112004 разница:  3.008293431945801
# Предсказанная стоимость: 5.2027607 , правильная стоимость: 0.010000005 разница:  5.192760691411133
# Предсказанная стоимость: 14.142096 , правильная стоимость: 15.240008 разница:  1.0979124342041011
# Предсказанная стоимость: 39.793396 , правильная стоимость: 0.25400013 разница:  39.53939586609375

# %%
СС_tuner = np.corrcoef(vec, y_test)
СС_tuner = СС_tuner[0][1]
print(f'Коэффициаент корреляция с истинными данными: {СС_tuner}')
# Out:
# Коэффициаент корреляция с истинными данными: 0.17616991482601785
