# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install deepface

# %%
from deepface import DeepFace
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing import image
import numpy as np
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import matplotlib
from skimage import io

# %%
img1_path = "/content/drive/MyDrive/11.jpg" 
img2_path = "/content/drive/MyDrive/12.png" 
img3_path = "/content/drive/MyDrive/13.jpg"
img4_path = "/content/drive/MyDrive/14.jpg"
img5_path = "/content/drive/MyDrive/15.jpg"
img6_path = "/content/drive/MyDrive/16.jpg"
img8_path = "/content/drive/MyDrive/18.jpg"

# %%
orig = cv2.imread(img1_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img2_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img3_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img4_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img6_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img8_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
orig = cv2.imread(img5_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img1_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img2_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img3_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img4_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img6_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img8_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img5_path, detector_backend = 'opencv')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
result = DeepFace.verify(img1_path, img2_path, distance_metric='euclidean', model_name='VGG-Face', detector_backend = 'opencv')
print( result["verified"])
# Out:
# True

# %%
result = DeepFace.verify(img1_path, img3_path, distance_metric='euclidean', model_name='VGG-Face', detector_backend = 'opencv')
print( result["verified"])
# Out:
# True

# %%
result = DeepFace.verify(img1_path, img4_path, distance_metric='euclidean', model_name='VGG-Face', detector_backend = 'opencv')
print( result["verified"])
# Out:
# False

# %%
result = DeepFace.verify(img1_path, img6_path, distance_metric='euclidean', model_name='VGG-Face', detector_backend = 'opencv')
print( result["verified"])
# Out:
# True

# %%
result = DeepFace.verify(img1_path, img8_path, distance_metric='euclidean', model_name='VGG-Face', detector_backend = 'opencv')
print( result["verified"])
# Out:
# False

# %%
result = DeepFace.verify(img1_path, img5_path, distance_metric='euclidean', model_name='VGG-Face', detector_backend = 'opencv')
print( result["verified"])
# Out:
# False
